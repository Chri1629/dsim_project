# %% [markdown]
# <a href="https://colab.research.google.com/github/Chri1629/dsim_project/blob/main/image/ambulanze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Progetto di Digital Signal & Image Management**
#
# ## **Parte 2 - Image Classification**
#
# *2020/2021*
#
# Peracchi Marco 800578
#
# Uccheddu Christian 800428

# %% [markdown]
# # Abstract
#
# La sezione di Image Classification si occupa di riconoscere da un'immagine se essa rappresenta o meno un mezzo di emergenza (ambulanze, polizia, vigili del fuoco etc), distinguendo questi mezzi da quelli comuni. Sono state utilizzate due reti per questo problema di classificazione. La prima rete è una **CNN definita da noi** mentre la seconda è una rete **pretrainata** sul task di imagenet.

# %% [markdown]
# # Operazioni di preprocessing

# %% [markdown]
# Importazione delle librerie necessarie:

# %%
import os
import numpy as np
from time import time
import re
import seaborn as sns
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import xception
from keras import layers

# %% [markdown]
# ## Lettura dei dati e importazione

# %% [markdown]
# Per importare i dati si utilizza Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

base_dir = "gdrive/MyDrive/ambulanze/"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Si procede a importare i dataset contenenti le informazioni sulle labels, ossia per ogni immagine è indicata a quale gruppo appartiene.

# %%
trainAV = pd.read_csv("gdrive/MyDrive/train.csv")
testAV = pd.read_csv("gdrive/MyDrive/test_vc2kHdQ.csv")

# %% [markdown]
# ** Le seguenti celle servono?? **

# %%
print(len(trainAV) + len(testAV))
# Out:
# 7290

# %%
trainAV.head()
# Out:
#   image_names  emergency_or_not
# 0    1503.jpg                 0
# 1    1420.jpg                 0
# 2    1764.jpg                 0
# 3    1356.jpg                 0
# 4    1117.jpg                 0

# %% [markdown]
# Visto la disposizione di immagini e le corrispondenti label si definisce una funzione *add_class* che permetterà di definire in maniera corretta le varie immagini:
#
# ATTENZIONE HO INSERITO UNA ROBA CHE NON SO SE FUNZIONA

# %%
def add_class():
  # Ciclo for su ogni immagine presente nella cartella
  for i, f in enumerate(sorted(os.listdir(base_dir))):

    # Controllo sull'estensione del file
    if f.endswith('.jpg'):

      # Ricerca e acquisizione numero dell'immagine
      name = re.search(r'^(\d+)\.jpg$', f).group(1)
      
      # Lettura dell'immagine
      a = plt.imread(base_dir + f)      
      fig = plt.figure(figsize=(4,4))
      ax = fig.add_subplot(111)

      ax.imshow(a)

      ax.axes.get_xaxis().set_visible(False)
      ax.axes.get_yaxis().set_visible(False)
      ax.set_frame_on(False)
      
      # Serie di if, se l'immagine letta è presente nel dataset train allora gli viene assegnata la label definita dal dataset
      if f in trainAV['image_names'].values:
        label = trainAV.loc[trainAV['image_names'] == f]['emergency_or_not'].values[0]
      
      # Se l'immagine è nel dataset test allora viene assegnata una label = 2
      elif f in testAV['image_names'].values:
        label = 2
      
      # Ora viene controllata la label appena assegnata
      # Se la label fosse 0 allora l'immagine viene salvata nella cartella corrispondente, e gli viene assegnato il nome salvato in precedenza
      if int(label) == 0:
          fig.savefig("gdrive/MyDrive/emergency_models/class_{}/{}.jpg".format(label, name), dpi = 100, bbox_inches = 'tight', pad_inches = 0)
      
      # Stessa procedura per la label 1
      elif int(label) == 1:
          fig.savefig("gdrive/MyDrive/emergency_models/class_{}/{}.jpg".format(label, name), dpi = 100, bbox_inches = 'tight', pad_inches = 0)
      
      # Infine se la label fosse 2 l'immagine viene inserita nel dataset di test
      elif int(label) == 2:
          fig.savefig("gdrive/MyDrive/emergency_models/class_test/{}.jpg".format(name), dpi = 100, bbox_inches = 'tight', pad_inches = 0)
    plt.close("all")
    print("Completato il: ", round(i/7290*100,2), "% dei file", end = "\r") #IN QUESTO PUNTO

# %%
add_class()
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Completato il:  31.43 % dei file
# Completato il:  31.44 % dei file
# Completato il:  31.45 % dei file
# Completato il:  31.47 % dei file
# Completato il:  31.48 % dei file
# Completato il:  31.5 % dei file
# Completato il:  31.51 % dei file
# Completato il:  31.52 % dei file
# Completato il:  31.54 % dei file
# Completato il:  31.55 % dei file
# Completato il:  31.56 % dei file
# Completato il:  31.58 % dei file
# Completato il:  31.59 % dei file
# Completato il:  31.6 % dei file
# Completato il:  31.62 % dei file
# Completato il:  31.63 % dei file
# Completato il:  31.65 % dei file
# Completato il:  31.66 % dei file
# Completato il:  31.67 % dei file
# Completato il:  31.69 % dei file
# Completato il:  31.7 % dei file
# Completato il:  31.71 % dei file
# Completato il:  31.73 % dei file
# Completato il:  31.74 % dei file
# Completato il:  31.76 % dei file
# Completato il:  31.77 % dei file
# Completato il:  31.78 % dei file
# Completato il:  31.8 % dei file
# Completato il:  31.81 % dei file
# Completato il:  31.82 % dei file
# Completato il:  31.84 % dei file
# Completato il:  31.85 % dei file
# Completato il:  31.87 % dei file
# Completato il:  31.88 % dei file
# Completato il:  31.89 % dei file
# Completato il:  31.91 % dei file
# Completato il:  31.92 % dei file
# Completato il:  31.93 % dei file
# Completato il:  31.95 % dei file
# Completato il:  31.96 % dei file
# Completato il:  31.98 % dei file
# Completato il:  31.99 % dei file
# Completato il:  32.0 % dei file
# Completato il:  32.02 % dei file
# Completato il:  32.03 % dei file
# Completato il:  32.04 % dei file
# Completato il:  32.06 % dei file
# Completato il:  32.07 % dei file
# Completato il:  32.09 % dei file
# Completato il:  32.1 % dei file
# Completato il:  32.11 % dei file
# Completato il:  32.13 % dei file
# Completato il:  32.14 % dei file
# Completato il:  32.15 % dei file
# Completato il:  32.17 % dei file
# Completato il:  32.18 % dei file
# Completato il:  32.19 % dei file
# Completato il:  32.21 % dei file
# Completato il:  32.22 % dei file
# Completato il:  32.24 % dei file
# Completato il:  32.25 % dei file
# Completato il:  32.26 % dei file
# Completato il:  32.28 % dei file
# Completato il:  32.29 % dei file
# Completato il:  32.3 % dei file
# Completato il:  32.32 % dei file
# Completato il:  32.33 % dei file
# Completato il:  32.35 % dei file
# Completato il:  32.36 % dei file
# Completato il:  32.37 % dei file
# Completato il:  32.39 % dei file
# Completato il:  32.4 % dei file
# Completato il:  32.41 % dei file
# Completato il:  32.43 % dei file
# Completato il:  32.44 % dei file
# Completato il:  32.46 % dei file
# Completato il:  32.47 % dei file
# Completato il:  32.48 % dei file
# Completato il:  32.5 % dei file
# Completato il:  32.51 % dei file
# Completato il:  32.52 % dei file
# Completato il:  32.54 % dei file
# Completato il:  32.55 % dei file
# Completato il:  32.57 % dei file
# Completato il:  32.58 % dei file
# Completato il:  32.59 % dei file
# Completato il:  32.61 % dei file
# Completato il:  32.62 % dei file
# Completato il:  32.63 % dei file
# Completato il:  32.65 % dei file
# Completato il:  32.66 % dei file
# Completato il:  32.67 % dei file
# Completato il:  32.69 % dei file
# Completato il:  32.7 % dei file
# Completato il:  32.72 % dei file
# Completato il:  32.73 % dei file
# Completato il:  32.74 % dei file
# Completato il:  32.76 % dei file
# Completato il:  32.77 % dei file
# Completato il:  32.78 % dei file
# Completato il:  32.8 % dei file
# Completato il:  32.81 % dei file
# Completato il:  32.83 % dei file
# Completato il:  32.84 % dei file
# Completato il:  32.85 % dei file
# Completato il:  32.87 % dei file
# Completato il:  32.88 % dei file
# Completato il:  32.89 % dei file
# Completato il:  32.91 % dei file
# Completato il:  32.92 % dei file
# Completato il:  32.94 % dei file
# Completato il:  32.95 % dei file
# Completato il:  32.96 % dei file
# Completato il:  32.98 % dei file
# Completato il:  32.99 % dei file
# Completato il:  33.0 % dei file
# Completato il:  33.02 % dei file
# Completato il:  33.03 % dei file
# Completato il:  33.05 % dei file
# Completato il:  33.06 % dei file
# Completato il:  33.07 % dei file
# Completato il:  33.09 % dei file
# Completato il:  33.1 % dei file
# Completato il:  33.11 % dei file
# Completato il:  33.13 % dei file
# Completato il:  33.14 % dei file
# Completato il:  33.16 % dei file
# Completato il:  33.17 % dei file
# Completato il:  33.18 % dei file
# Completato il:  33.2 % dei file
# Completato il:  33.21 % dei file
# Completato il:  33.22 % dei file
# Completato il:  33.24 % dei file
# Completato il:  33.25 % dei file
# Completato il:  33.26 % dei file
# Completato il:  33.28 % dei file
# Completato il:  33.29 % dei file
# Completato il:  33.31 % dei file
# Completato il:  33.32 % dei file
# Completato il:  33.33 % dei file
# Completato il:  33.35 % dei file
# Completato il:  33.36 % dei file
# Completato il:  33.37 % dei file
# Completato il:  33.39 % dei file
# Completato il:  33.4 % dei file
# Completato il:  33.42 % dei file
# Completato il:  33.43 % dei file
# Completato il:  33.44 % dei file
# Completato il:  33.46 % dei file
# Completato il:  33.47 % dei file
# Completato il:  33.48 % dei file
# Completato il:  33.5 % dei file
# Completato il:  33.51 % dei file
# Completato il:  33.53 % dei file
# Completato il:  33.54 % dei file
# Completato il:  33.55 % dei file
# Completato il:  33.57 % dei file
# Completato il:  33.58 % dei file
# Completato il:  33.59 % dei file
# Completato il:  33.61 % dei file
# Completato il:  33.62 % dei file
# Completato il:  33.64 % dei file
# Completato il:  33.65 % dei file
# Completato il:  33.66 % dei file
# Completato il:  33.68 % dei file
# Completato il:  33.69 % dei file
# Completato il:  33.7 % dei file
# Completato il:  33.72 % dei file
# Completato il:  33.73 % dei file
# Completato il:  33.74 % dei file
# Completato il:  33.76 % dei file
# Completato il:  33.77 % dei file
# Completato il:  33.79 % dei file
# Completato il:  33.8 % dei file
# Completato il:  33.81 % dei file
# Completato il:  33.83 % dei file
# Completato il:  33.84 % dei file
# Completato il:  33.85 % dei file
# Completato il:  33.87 % dei file
# Completato il:  33.88 % dei file
# Completato il:  33.9 % dei file
# Completato il:  33.91 % dei file
# Completato il:  33.92 % dei file
# Completato il:  33.94 % dei file
# Completato il:  33.95 % dei file
# Completato il:  33.96 % dei file
# Completato il:  33.98 % dei file
# Completato il:  33.99 % dei file
# Completato il:  34.01 % dei file
# Completato il:  34.02 % dei file
# Completato il:  34.03 % dei file
# Completato il:  34.05 % dei file
# Completato il:  34.06 % dei file
# Completato il:  34.07 % dei file
# Completato il:  34.09 % dei file
# Completato il:  34.1 % dei file
# Completato il:  34.12 % dei file
# Completato il:  34.13 % dei file
# Completato il:  34.14 % dei file
# Completato il:  34.16 % dei file
# Completato il:  34.17 % dei file
# Completato il:  34.18 % dei file
# Completato il:  34.2 % dei file
# Completato il:  34.21 % dei file
# Completato il:  34.22 % dei file
# Completato il:  34.24 % dei file
# Completato il:  34.25 % dei file
# Completato il:  34.27 % dei file
# Completato il:  34.28 % dei file
# Completato il:  34.29 % dei file
# Completato il:  34.31 % dei file
# Completato il:  34.32 % dei file
# Completato il:  34.33 % dei file
# Completato il:  34.35 % dei file
# Completato il:  34.36 % dei file
# Completato il:  34.38 % dei file
# Completato il:  34.39 % dei file
# Completato il:  34.4 % dei file
# Completato il:  34.42 % dei file
# Completato il:  34.43 % dei file
# Completato il:  34.44 % dei file
# Completato il:  34.46 % dei file
# Completato il:  34.47 % dei file
# Completato il:  34.49 % dei file
# Completato il:  34.5 % dei file
# Completato il:  34.51 % dei file
# Completato il:  34.53 % dei file
# Completato il:  34.54 % dei file
# Completato il:  34.55 % dei file
# Completato il:  34.57 % dei file
# Completato il:  34.58 % dei file
# Completato il:  34.6 % dei file
# Completato il:  34.61 % dei file
# Completato il:  34.62 % dei file
# Completato il:  34.64 % dei file
# Completato il:  34.65 % dei file
# Completato il:  34.66 % dei file
# Completato il:  34.68 % dei file
# Completato il:  34.69 % dei file
# Completato il:  34.71 % dei file
# Completato il:  34.72 % dei file
# Completato il:  34.73 % dei file
# Completato il:  34.75 % dei file
# Completato il:  34.76 % dei file
# Completato il:  34.77 % dei file
# Completato il:  34.79 % dei file
# Completato il:  34.8 % dei file
# Completato il:  34.81 % dei file
# Completato il:  34.83 % dei file
# Completato il:  34.84 % dei file
# Completato il:  34.86 % dei file
# Completato il:  34.87 % dei file
# Completato il:  34.88 % dei file
# Completato il:  34.9 % dei file
# Completato il:  34.91 % dei file
# Completato il:  34.92 % dei file
# Completato il:  34.94 % dei file
# Completato il:  34.95 % dei file
# Completato il:  34.97 % dei file
# Completato il:  34.98 % dei file
# Completato il:  34.99 % dei file
# Completato il:  35.01 % dei file
# Completato il:  35.02 % dei file
# Completato il:  35.03 % dei file
# Completato il:  35.05 % dei file
# Completato il:  35.06 % dei file
# Completato il:  35.08 % dei file
# Completato il:  35.09 % dei file
# Completato il:  35.1 % dei file
# Completato il:  35.12 % dei file
# Completato il:  35.13 % dei file
# Completato il:  35.14 % dei file
# Completato il:  35.16 % dei file
# Completato il:  35.17 % dei file
# Completato il:  35.19 % dei file
# Completato il:  35.2 % dei file
# Completato il:  35.21 % dei file
# Completato il:  35.23 % dei file
# Completato il:  35.24 % dei file
# Completato il:  35.25 % dei file
# Completato il:  35.27 % dei file
# Completato il:  35.28 % dei file
# Completato il:  35.29 % dei file
# Completato il:  35.31 % dei file
# Completato il:  35.32 % dei file
# Completato il:  35.34 % dei file
# Completato il:  35.35 % dei file
# Completato il:  35.36 % dei file
# Completato il:  35.38 % dei file
# Completato il:  35.39 % dei file
# Completato il:  35.4 % dei file
# Completato il:  35.42 % dei file
# Completato il:  35.43 % dei file
# Completato il:  35.45 % dei file
# Completato il:  35.46 % dei file
# Completato il:  35.47 % dei file
# Completato il:  35.49 % dei file
# Completato il:  35.5 % dei file
# Completato il:  35.51 % dei file
# Completato il:  35.53 % dei file
# Completato il:  35.54 % dei file
# Completato il:  35.56 % dei file
# Completato il:  35.57 % dei file
# Completato il:  35.58 % dei file
# Completato il:  35.6 % dei file
# Completato il:  35.61 % dei file
# Completato il:  35.62 % dei file
# Completato il:  35.64 % dei file
# Completato il:  35.65 % dei file
# Completato il:  35.67 % dei file
# Completato il:  35.68 % dei file
# Completato il:  35.69 % dei file
# Completato il:  35.71 % dei file
# Completato il:  35.72 % dei file
# Completato il:  35.73 % dei file
# Completato il:  35.75 % dei file
# Completato il:  35.76 % dei file
# Completato il:  35.78 % dei file
# Completato il:  35.79 % dei file
# Completato il:  35.8 % dei file
# Completato il:  35.82 % dei file
# Completato il:  35.83 % dei file
# Completato il:  35.84 % dei file
# Completato il:  35.86 % dei file
# Completato il:  35.87 % dei file
# Completato il:  35.88 % dei file
# Completato il:  35.9 % dei file
# Completato il:  35.91 % dei file
# Completato il:  35.93 % dei file
# Completato il:  35.94 % dei file
# Completato il:  35.95 % dei file
# Completato il:  35.97 % dei file
# Completato il:  35.98 % dei file
# Completato il:  35.99 % dei file
# Completato il:  36.01 % dei file
# Completato il:  36.02 % dei file
# Completato il:  36.04 % dei file
# Completato il:  36.05 % dei file
# Completato il:  36.06 % dei file
# Completato il:  36.08 % dei file
# Completato il:  36.09 % dei file
# Completato il:  36.1 % dei file
# Completato il:  36.12 % dei file
# Completato il:  36.13 % dei file
# Completato il:  36.15 % dei file
# Completato il:  36.16 % dei file
# Completato il:  36.17 % dei file
# Completato il:  36.19 % dei file
# Completato il:  36.2 % dei file
# Completato il:  36.21 % dei file
# Completato il:  36.23 % dei file
# Completato il:  36.24 % dei file
# Completato il:  36.26 % dei file
# Completato il:  36.27 % dei file
# Completato il:  36.28 % dei file
# Completato il:  36.3 % dei file
# Completato il:  36.31 % dei file
# Completato il:  36.32 % dei file
# Completato il:  36.34 % dei file
# Completato il:  36.35 % dei file
# Completato il:  36.36 % dei file
# Completato il:  36.38 % dei file
# Completato il:  36.39 % dei file
# Completato il:  36.41 % dei file
# Completato il:  36.42 % dei file
# Completato il:  36.43 % dei file
# Completato il:  36.45 % dei file
# Completato il:  36.46 % dei file
# Completato il:  36.47 % dei file
# Completato il:  36.49 % dei file
# Completato il:  36.5 % dei file
# Completato il:  36.52 % dei file
# Completato il:  36.53 % dei file
# Completato il:  36.54 % dei file
# Completato il:  36.56 % dei file
# Completato il:  36.57 % dei file
# Completato il:  36.58 % dei file
# Completato il:  36.6 % dei file
# Completato il:  36.61 % dei file
# Completato il:  36.63 % dei file
# Completato il:  36.64 % dei file
# Completato il:  36.65 % dei file
# Completato il:  36.67 % dei file
# Completato il:  36.68 % dei file
# Completato il:  36.69 % dei file
# Completato il:  36.71 % dei file
# Completato il:  36.72 % dei file
# Completato il:  36.74 % dei file
# Completato il:  36.75 % dei file
# Completato il:  36.76 % dei file
# Completato il:  36.78 % dei file
# Completato il:  36.79 % dei file
# Completato il:  36.8 % dei file
# Completato il:  36.82 % dei file
# Completato il:  36.83 % dei file
# Completato il:  36.84 % dei file
# Completato il:  36.86 % dei file
# Completato il:  36.87 % dei file
# Completato il:  36.89 % dei file
# Completato il:  36.9 % dei file
# Completato il:  36.91 % dei file
# Completato il:  36.93 % dei file
# Completato il:  36.94 % dei file
# Completato il:  36.95 % dei file
# Completato il:  36.97 % dei file
# Completato il:  36.98 % dei file
# Completato il:  37.0 % dei file
# Completato il:  37.01 % dei file
# Completato il:  37.02 % dei file
# Completato il:  37.04 % dei file
# Completato il:  37.05 % dei file
# Completato il:  37.06 % dei file
# Completato il:  37.08 % dei file
# Completato il:  37.09 % dei file
# Completato il:  37.11 % dei file
# Completato il:  37.12 % dei file
# Completato il:  37.13 % dei file
# Completato il:  37.15 % dei file
# Completato il:  37.16 % dei file
# Completato il:  37.17 % dei file
# Completato il:  37.19 % dei file
# Completato il:  37.2 % dei file
# Completato il:  37.22 % dei file
# Completato il:  37.23 % dei file
# Completato il:  37.24 % dei file
# Completato il:  37.26 % dei file
# Completato il:  37.27 % dei file
# Completato il:  37.28 % dei file
# Completato il:  37.3 % dei file
# Completato il:  37.31 % dei file
# Completato il:  37.33 % dei file
# Completato il:  37.34 % dei file
# Completato il:  37.35 % dei file
# Completato il:  37.37 % dei file
# Completato il:  37.38 % dei file
# Completato il:  37.39 % dei file
# Completato il:  37.41 % dei file
# Completato il:  37.42 % dei file
# Completato il:  37.43 % dei file
# Completato il:  37.45 % dei file
# Completato il:  37.46 % dei file
# Completato il:  37.48 % dei file
# Completato il:  37.49 % dei file
# Completato il:  37.5 % dei file
# Completato il:  37.52 % dei file
# Completato il:  37.53 % dei file
# Completato il:  37.54 % dei file
# Completato il:  37.56 % dei file
# Completato il:  37.57 % dei file
# Completato il:  37.59 % dei file
# Completato il:  37.6 % dei file
# Completato il:  37.61 % dei file
# Completato il:  37.63 % dei file
# Completato il:  37.64 % dei file
# Completato il:  37.65 % dei file
# Completato il:  37.67 % dei file
# Completato il:  37.68 % dei file
# Completato il:  37.7 % dei file
# Completato il:  37.71 % dei file
# Completato il:  37.72 % dei file
# Completato il:  37.74 % dei file
# Completato il:  37.75 % dei file
# Completato il:  37.76 % dei file
# Completato il:  37.78 % dei file
# Completato il:  37.79 % dei file
# Completato il:  37.81 % dei file
# Completato il:  37.82 % dei file
# Completato il:  37.83 % dei file
# Completato il:  37.85 % dei file
# Completato il:  37.86 % dei file
# Completato il:  37.87 % dei file
# Completato il:  37.89 % dei file
# Completato il:  37.9 % dei file
# Completato il:  37.91 % dei file
# Completato il:  37.93 % dei file
# Completato il:  37.94 % dei file
# Completato il:  37.96 % dei file
# Completato il:  37.97 % dei file
# Completato il:  37.98 % dei file
# Completato il:  38.0 % dei file
# Completato il:  38.01 % dei file
# Completato il:  38.02 % dei file
# Completato il:  38.04 % dei file
# Completato il:  38.05 % dei file
# Completato il:  38.07 % dei file
# Completato il:  38.08 % dei file
# Completato il:  38.09 % dei file
# Completato il:  38.11 % dei file
# Completato il:  38.12 % dei file
# Completato il:  38.13 % dei file
# Completato il:  38.15 % dei file
# Completato il:  38.16 % dei file
# Completato il:  38.18 % dei file
# Completato il:  38.19 % dei file
# Completato il:  38.2 % dei file
# Completato il:  38.22 % dei file
# Completato il:  38.23 % dei file
# Completato il:  38.24 % dei file
# Completato il:  38.26 % dei file
# Completato il:  38.27 % dei file
# Completato il:  38.29 % dei file
# Completato il:  38.3 % dei file
# Completato il:  38.31 % dei file
# Completato il:  38.33 % dei file
# Completato il:  38.34 % dei file
# Completato il:  38.35 % dei file
# Completato il:  38.37 % dei file
# Completato il:  38.38 % dei file
# Completato il:  38.4 % dei file
# Completato il:  38.41 % dei file
# Completato il:  38.42 % dei file
# Completato il:  38.44 % dei file
# Completato il:  38.45 % dei file
# Completato il:  38.46 % dei file
# Completato il:  38.48 % dei file
# Completato il:  38.49 % dei file
# Completato il:  38.5 % dei file
# Completato il:  38.52 % dei file
# Completato il:  38.53 % dei file
# Completato il:  38.55 % dei file
# Completato il:  38.56 % dei file
# Completato il:  38.57 % dei file
# Completato il:  38.59 % dei file
# Completato il:  38.6 % dei file
# Completato il:  38.61 % dei file
# Completato il:  38.63 % dei file
# Completato il:  38.64 % dei file
# Completato il:  38.66 % dei file
# Completato il:  38.67 % dei file
# Completato il:  38.68 % dei file
# Completato il:  38.7 % dei file
# Completato il:  38.71 % dei file
# Completato il:  38.72 % dei file
# Completato il:  38.74 % dei file
# Completato il:  38.75 % dei file
# Completato il:  38.77 % dei file
# Completato il:  38.78 % dei file
# Completato il:  38.79 % dei file
# Completato il:  38.81 % dei file
# Completato il:  38.82 % dei file
# Completato il:  38.83 % dei file
# Completato il:  38.85 % dei file
# Completato il:  38.86 % dei file
# Completato il:  38.88 % dei file
# Completato il:  38.89 % dei file
# Completato il:  38.9 % dei file
# Completato il:  38.92 % dei file
# Completato il:  38.93 % dei file
# Completato il:  38.94 % dei file
# Completato il:  38.96 % dei file
# Completato il:  38.97 % dei file
# Completato il:  38.98 % dei file
# Completato il:  39.0 % dei file
# Completato il:  39.01 % dei file
# Completato il:  39.03 % dei file
# Completato il:  39.04 % dei file
# Completato il:  39.05 % dei file
# Completato il:  39.07 % dei file
# Completato il:  39.08 % dei file
# Completato il:  39.09 % dei file
# Completato il:  39.11 % dei file
# Completato il:  39.12 % dei file
# Completato il:  39.14 % dei file
# Completato il:  39.15 % dei file
# Completato il:  39.16 % dei file
# Completato il:  39.18 % dei file
# Completato il:  39.19 % dei file
# Completato il:  39.2 % dei file
# Completato il:  39.22 % dei file
# Completato il:  39.23 % dei file
# Completato il:  39.25 % dei file
# Completato il:  39.26 % dei file
# Completato il:  39.27 % dei file
# Completato il:  39.29 % dei file
# Completato il:  39.3 % dei file
# Completato il:  39.31 % dei file
# Completato il:  39.33 % dei file
# Completato il:  39.34 % dei file
# Completato il:  39.36 % dei file
# Completato il:  39.37 % dei file
# Completato il:  39.38 % dei file
# Completato il:  39.4 % dei file
# Completato il:  39.41 % dei file
# Completato il:  39.42 % dei file
# Completato il:  39.44 % dei file
# Completato il:  39.45 % dei file
# Completato il:  39.47 % dei file
# Completato il:  39.48 % dei file
# Completato il:  39.49 % dei file
# Completato il:  39.51 % dei file
# Completato il:  39.52 % dei file
# Completato il:  39.53 % dei file
# Completato il:  39.55 % dei file
# Completato il:  39.56 % dei file
# Completato il:  39.57 % dei file
# Completato il:  39.59 % dei file
# Completato il:  39.6 % dei file
# Completato il:  39.62 % dei file
# Completato il:  39.63 % dei file
# Completato il:  39.64 % dei file
# Completato il:  39.66 % dei file
# Completato il:  39.67 % dei file
# Completato il:  39.68 % dei file
# Completato il:  39.7 % dei file
# Completato il:  39.71 % dei file
# Completato il:  39.73 % dei file
# Completato il:  39.74 % dei file
# Completato il:  39.75 % dei file
# Completato il:  39.77 % dei file
# Completato il:  39.78 % dei file
# Completato il:  39.79 % dei file
# Completato il:  39.81 % dei file
# Completato il:  39.82 % dei file
# Completato il:  39.84 % dei file
# Completato il:  39.85 % dei file
# Completato il:  39.86 % dei file
# Completato il:  39.88 % dei file
# Completato il:  39.89 % dei file
# Completato il:  39.9 % dei file
# Completato il:  39.92 % dei file
# Completato il:  39.93 % dei file
# Completato il:  39.95 % dei file
# Completato il:  39.96 % dei file
# Completato il:  39.97 % dei file
# Completato il:  39.99 % dei file
# Completato il:  40.0 % dei file
# Completato il:  40.01 % dei file
# Completato il:  40.03 % dei file
# Completato il:  40.04 % dei file
# Completato il:  40.05 % dei file
# Completato il:  40.07 % dei file
# Completato il:  40.08 % dei file
# Completato il:  40.1 % dei file
# Completato il:  40.11 % dei file
# Completato il:  40.12 % dei file
# Completato il:  40.14 % dei file
# Completato il:  40.15 % dei file
# Completato il:  40.16 % dei file
# Completato il:  40.18 % dei file
# Completato il:  40.19 % dei file
# Completato il:  40.21 % dei file
# Completato il:  40.22 % dei file
# Completato il:  40.23 % dei file
# Completato il:  40.25 % dei file
# Completato il:  40.26 % dei file
# Completato il:  40.27 % dei file
# Completato il:  40.29 % dei file
# Completato il:  40.3 % dei file
# Completato il:  40.32 % dei file
# Completato il:  40.33 % dei file
# Completato il:  40.34 % dei file
# Completato il:  40.36 % dei file
# Completato il:  40.37 % dei file
# Completato il:  40.38 % dei file
# Completato il:  40.4 % dei file
# Completato il:  40.41 % dei file
# Completato il:  40.43 % dei file
# Completato il:  40.44 % dei file
# Completato il:  40.45 % dei file
# Completato il:  40.47 % dei file
# Completato il:  40.48 % dei file
# Completato il:  40.49 % dei file
# Completato il:  40.51 % dei file
# Completato il:  40.52 % dei file
# Completato il:  40.53 % dei file
# Completato il:  40.55 % dei file
# Completato il:  40.56 % dei file
# Completato il:  40.58 % dei file
# Completato il:  40.59 % dei file
# Completato il:  40.6 % dei file
# Completato il:  40.62 % dei file
# Completato il:  40.63 % dei file
# Completato il:  40.64 % dei file
# Completato il:  40.66 % dei file
# Completato il:  40.67 % dei file
# Completato il:  40.69 % dei file
# Completato il:  40.7 % dei file
# Completato il:  40.71 % dei file
# Completato il:  40.73 % dei file
# Completato il:  40.74 % dei file
# Completato il:  40.75 % dei file
# Completato il:  40.77 % dei file
# Completato il:  40.78 % dei file
# Completato il:  40.8 % dei file
# Completato il:  40.81 % dei file
# Completato il:  40.82 % dei file
# Completato il:  40.84 % dei file
# Completato il:  40.85 % dei file
# Completato il:  40.86 % dei file
# Completato il:  40.88 % dei file
# Completato il:  40.89 % dei file
# Completato il:  40.91 % dei file
# Completato il:  40.92 % dei file
# Completato il:  40.93 % dei file
# Completato il:  40.95 % dei file
# Completato il:  40.96 % dei file
# Completato il:  40.97 % dei file
# Completato il:  40.99 % dei file
# Completato il:  41.0 % dei file
# Completato il:  41.02 % dei file
# Completato il:  41.03 % dei file
# Completato il:  41.04 % dei file
# Completato il:  41.06 % dei file
# Completato il:  41.07 % dei file
# Completato il:  41.08 % dei file
# Completato il:  41.1 % dei file
# Completato il:  41.11 % dei file
# Completato il:  41.12 % dei file
# Completato il:  41.14 % dei file
# Completato il:  41.15 % dei file
# Completato il:  41.17 % dei file
# Completato il:  41.18 % dei file
# Completato il:  41.19 % dei file
# Completato il:  41.21 % dei file
# Completato il:  41.22 % dei file
# Completato il:  41.23 % dei file
# Completato il:  41.25 % dei file
# Completato il:  41.26 % dei file
# Completato il:  41.28 % dei file
# Completato il:  41.29 % dei file
# Completato il:  41.3 % dei file
# Completato il:  41.32 % dei file
# Completato il:  41.33 % dei file
# Completato il:  41.34 % dei file
# Completato il:  41.36 % dei file
# Completato il:  41.37 % dei file
# Completato il:  41.39 % dei file
# Completato il:  41.4 % dei file
# Completato il:  41.41 % dei file
# Completato il:  41.43 % dei file
# Completato il:  41.44 % dei file
# Completato il:  41.45 % dei file
# Completato il:  41.47 % dei file
# Completato il:  41.48 % dei file
# Completato il:  41.5 % dei file
# Completato il:  41.51 % dei file
# Completato il:  41.52 % dei file
# Completato il:  41.54 % dei file
# Completato il:  41.55 % dei file
# Completato il:  41.56 % dei file
# Completato il:  41.58 % dei file
# Completato il:  41.59 % dei file
# Completato il:  41.6 % dei file
# Completato il:  41.62 % dei file
# Completato il:  41.63 % dei file
# Completato il:  41.65 % dei file
# Completato il:  41.66 % dei file
# Completato il:  41.67 % dei file
# Completato il:  41.69 % dei file
# Completato il:  41.7 % dei file
# Completato il:  41.71 % dei file
# Completato il:  41.73 % dei file
# Completato il:  41.74 % dei file
# Completato il:  41.76 % dei file
# Completato il:  41.77 % dei file
# Completato il:  41.78 % dei file
# Completato il:  41.8 % dei file
# Completato il:  41.81 % dei file
# Completato il:  41.82 % dei file
# Completato il:  41.84 % dei file
# Completato il:  41.85 % dei file
# Completato il:  41.87 % dei file
# Completato il:  41.88 % dei file
# Completato il:  41.89 % dei file
# Completato il:  41.91 % dei file
# Completato il:  41.92 % dei file
# Completato il:  41.93 % dei file
# Completato il:  41.95 % dei file
# Completato il:  41.96 % dei file
# Completato il:  41.98 % dei file
# Completato il:  41.99 % dei file
# Completato il:  42.0 % dei file
# Completato il:  42.02 % dei file
# Completato il:  42.03 % dei file
# Completato il:  42.04 % dei file
# Completato il:  42.06 % dei file
# Completato il:  42.07 % dei file
# Completato il:  42.09 % dei file
# Completato il:  42.1 % dei file
# Completato il:  42.11 % dei file
# Completato il:  42.13 % dei file
# Completato il:  42.14 % dei file
# Completato il:  42.15 % dei file
# Completato il:  42.17 % dei file
# Completato il:  42.18 % dei file
# Completato il:  42.19 % dei file
# Completato il:  42.21 % dei file
# Completato il:  42.22 % dei file
# Completato il:  42.24 % dei file
# Completato il:  42.25 % dei file
# Completato il:  42.26 % dei file
# Completato il:  42.28 % dei file
# Completato il:  42.29 % dei file
# Completato il:  42.3 % dei file
# Completato il:  42.32 % dei file
# Completato il:  42.33 % dei file
# Completato il:  42.35 % dei file
# Completato il:  42.36 % dei file
# Completato il:  42.37 % dei file
# Completato il:  42.39 % dei file
# Completato il:  42.4 % dei file
# Completato il:  42.41 % dei file
# Completato il:  42.43 % dei file
# Completato il:  42.44 % dei file
# Completato il:  42.46 % dei file
# Completato il:  42.47 % dei file
# Completato il:  42.48 % dei file
# Completato il:  42.5 % dei file
# Completato il:  42.51 % dei file
# Completato il:  42.52 % dei file
# Completato il:  42.54 % dei file
# Completato il:  42.55 % dei file
# Completato il:  42.57 % dei file
# Completato il:  42.58 % dei file
# Completato il:  42.59 % dei file
# Completato il:  42.61 % dei file
# Completato il:  42.62 % dei file
# Completato il:  42.63 % dei file
# Completato il:  42.65 % dei file
# Completato il:  42.66 % dei file
# Completato il:  42.67 % dei file
# Completato il:  42.69 % dei file
# Completato il:  42.7 % dei file
# Completato il:  42.72 % dei file
# Completato il:  42.73 % dei file
# Completato il:  42.74 % dei file
# Completato il:  42.76 % dei file
# Completato il:  42.77 % dei file
# Completato il:  42.78 % dei file
# Completato il:  42.8 % dei file
# Completato il:  42.81 % dei file
# Completato il:  42.83 % dei file
# Completato il:  42.84 % dei file
# Completato il:  42.85 % dei file
# Completato il:  42.87 % dei file
# Completato il:  42.88 % dei file
# Completato il:  42.89 % dei file
# Completato il:  42.91 % dei file
# Completato il:  42.92 % dei file
# Completato il:  42.94 % dei file
# Completato il:  42.95 % dei file
# Completato il:  42.96 % dei file
# Completato il:  42.98 % dei file
# Completato il:  42.99 % dei file
# Completato il:  43.0 % dei file
# Completato il:  43.02 % dei file
# Completato il:  43.03 % dei file
# Completato il:  43.05 % dei file
# Completato il:  43.06 % dei file
# Completato il:  43.07 % dei file
# Completato il:  43.09 % dei file
# Completato il:  43.1 % dei file
# Completato il:  43.11 % dei file
# Completato il:  43.13 % dei file
# Completato il:  43.14 % dei file
# Completato il:  43.16 % dei file
# Completato il:  43.17 % dei file
# Completato il:  43.18 % dei file
# Completato il:  43.2 % dei file
# Completato il:  43.21 % dei file
# Completato il:  43.22 % dei file
# Completato il:  43.24 % dei file
# Completato il:  43.25 % dei file
# Completato il:  43.26 % dei file
# Completato il:  43.28 % dei file
# Completato il:  43.29 % dei file
# Completato il:  43.31 % dei file
# Completato il:  43.32 % dei file
# Completato il:  43.33 % dei file
# Completato il:  43.35 % dei file
# Completato il:  43.36 % dei file
# Completato il:  43.37 % dei file
# Completato il:  43.39 % dei file
# Completato il:  43.4 % dei file
# Completato il:  43.42 % dei file
# Completato il:  43.43 % dei file
# Completato il:  43.44 % dei file
# Completato il:  43.46 % dei file
# Completato il:  43.47 % dei file
# Completato il:  43.48 % dei file
# Completato il:  43.5 % dei file
# Completato il:  43.51 % dei file
# Completato il:  43.53 % dei file
# Completato il:  43.54 % dei file
# Completato il:  43.55 % dei file
# Completato il:  43.57 % dei file
# Completato il:  43.58 % dei file
# Completato il:  43.59 % dei file
# Completato il:  43.61 % dei file
# Completato il:  43.62 % dei file
# Completato il:  43.64 % dei file
# Completato il:  43.65 % dei file
# Completato il:  43.66 % dei file
# Completato il:  43.68 % dei file
# Completato il:  43.69 % dei file
# Completato il:  43.7 % dei file
# Completato il:  43.72 % dei file
# Completato il:  43.73 % dei file
# Completato il:  43.74 % dei file
# Completato il:  43.76 % dei file
# Completato il:  43.77 % dei file
# Completato il:  43.79 % dei file
# Completato il:  43.8 % dei file
# Completato il:  43.81 % dei file
# Completato il:  43.83 % dei file
# Completato il:  43.84 % dei file
# Completato il:  43.85 % dei file
# Completato il:  43.87 % dei file
# Completato il:  43.88 % dei file
# Completato il:  43.9 % dei file
# Completato il:  43.91 % dei file
# Completato il:  43.92 % dei file
# Completato il:  43.94 % dei file
# Completato il:  43.95 % dei file
# Completato il:  43.96 % dei file
# Completato il:  43.98 % dei file
# Completato il:  43.99 % dei file
# Completato il:  44.01 % dei file
# Completato il:  44.02 % dei file
# Completato il:  44.03 % dei file
# Completato il:  44.05 % dei file
# Completato il:  44.06 % dei file
# Completato il:  44.07 % dei file
# Completato il:  44.09 % dei file
# Completato il:  44.1 % dei file
# Completato il:  44.12 % dei file
# Completato il:  44.13 % dei file
# Completato il:  44.14 % dei file
# Completato il:  44.16 % dei file
# Completato il:  44.17 % dei file
# Completato il:  44.18 % dei file
# Completato il:  44.2 % dei file
# Completato il:  44.21 % dei file
# Completato il:  44.22 % dei file
# Completato il:  44.24 % dei file
# Completato il:  44.25 % dei file
# Completato il:  44.27 % dei file
# Completato il:  44.28 % dei file
# Completato il:  44.29 % dei file
# Completato il:  44.31 % dei file
# Completato il:  44.32 % dei file
# Completato il:  44.33 % dei file
# Completato il:  44.35 % dei file
# Completato il:  44.36 % dei file
# Completato il:  44.38 % dei file
# Completato il:  44.39 % dei file
# Completato il:  44.4 % dei file
# Completato il:  44.42 % dei file
# Completato il:  44.43 % dei file
# Completato il:  44.44 % dei file
# Completato il:  44.46 % dei file
# Completato il:  44.47 % dei file
# Completato il:  44.49 % dei file
# Completato il:  44.5 % dei file
# Completato il:  44.51 % dei file
# Completato il:  44.53 % dei file
# Completato il:  44.54 % dei file
# Completato il:  44.55 % dei file
# Completato il:  44.57 % dei file
# Completato il:  44.58 % dei file
# Completato il:  44.6 % dei file
# Completato il:  44.61 % dei file
# Completato il:  44.62 % dei file
# Completato il:  44.64 % dei file
# Completato il:  44.65 % dei file
# Completato il:  44.66 % dei file
# Completato il:  44.68 % dei file
# Completato il:  44.69 % dei file
# Completato il:  44.71 % dei file
# Completato il:  44.72 % dei file
# Completato il:  44.73 % dei file
# Completato il:  44.75 % dei file
# Completato il:  44.76 % dei file
# Completato il:  44.77 % dei file
# Completato il:  44.79 % dei file
# Completato il:  44.8 % dei file
# Completato il:  44.81 % dei file
# Completato il:  44.83 % dei file
# Completato il:  44.84 % dei file
# Completato il:  44.86 % dei file
# Completato il:  44.87 % dei file
# Completato il:  44.88 % dei file
# Completato il:  44.9 % dei file
# Completato il:  44.91 % dei file
# Completato il:  44.92 % dei file
# Completato il:  44.94 % dei file
# Completato il:  44.95 % dei file
# Completato il:  44.97 % dei file
# Completato il:  44.98 % dei file
# Completato il:  44.99 % dei file
# Completato il:  45.01 % dei file
# Completato il:  45.02 % dei file
# Completato il:  45.03 % dei file
# Completato il:  45.05 % dei file
# Completato il:  45.06 % dei file
# Completato il:  45.08 % dei file
# Completato il:  45.09 % dei file
# Completato il:  45.1 % dei file
# Completato il:  45.12 % dei file
# Completato il:  45.13 % dei file
# Completato il:  45.14 % dei file
# Completato il:  45.16 % dei file
# Completato il:  45.17 % dei file
# Completato il:  45.19 % dei file
# Completato il:  45.2 % dei file
# Completato il:  45.21 % dei file
# Completato il:  45.23 % dei file
# Completato il:  45.24 % dei file
# Completato il:  45.25 % dei file
# Completato il:  45.27 % dei file
# Completato il:  45.28 % dei file
# Completato il:  45.29 % dei file
# Completato il:  45.31 % dei file
# Completato il:  45.32 % dei file
# Completato il:  45.34 % dei file
# Completato il:  45.35 % dei file
# Completato il:  45.36 % dei file
# Completato il:  45.38 % dei file
# Completato il:  45.39 % dei file
# Completato il:  45.4 % dei file
# Completato il:  45.42 % dei file
# Completato il:  45.43 % dei file
# Completato il:  45.45 % dei file
# Completato il:  45.46 % dei file
# Completato il:  45.47 % dei file
# Completato il:  45.49 % dei file
# Completato il:  45.5 % dei file
# Completato il:  45.51 % dei file
# Completato il:  45.53 % dei file
# Completato il:  45.54 % dei file
# Completato il:  45.56 % dei file
# Completato il:  45.57 % dei file
# Completato il:  45.58 % dei file
# Completato il:  45.6 % dei file
# Completato il:  45.61 % dei file
# Completato il:  45.62 % dei file
# Completato il:  45.64 % dei file
# Completato il:  45.65 % dei file
# Completato il:  45.67 % dei file
# Completato il:  45.68 % dei file
# Completato il:  45.69 % dei file
# Completato il:  45.71 % dei file
# Completato il:  45.72 % dei file
# Completato il:  45.73 % dei file
# Completato il:  45.75 % dei file
# Completato il:  45.76 % dei file
# Completato il:  45.78 % dei file
# Completato il:  45.79 % dei file
# Completato il:  45.8 % dei file
# Completato il:  45.82 % dei file
# Completato il:  45.83 % dei file
# Completato il:  45.84 % dei file
# Completato il:  45.86 % dei file
# Completato il:  45.87 % dei file
# Completato il:  45.88 % dei file
# Completato il:  45.9 % dei file
# Completato il:  45.91 % dei file
# Completato il:  45.93 % dei file
# Completato il:  45.94 % dei file
# Completato il:  45.95 % dei file
# Completato il:  45.97 % dei file
# Completato il:  45.98 % dei file
# Completato il:  45.99 % dei file
# Completato il:  46.01 % dei file
# Completato il:  46.02 % dei file
# Completato il:  46.04 % dei file
# Completato il:  46.05 % dei file
# Completato il:  46.06 % dei file
# Completato il:  46.08 % dei file
# Completato il:  46.09 % dei file
# Completato il:  46.1 % dei file
# Completato il:  46.12 % dei file
# Completato il:  46.13 % dei file
# Completato il:  46.15 % dei file
# Completato il:  46.16 % dei file
# Completato il:  46.17 % dei file
# Completato il:  46.19 % dei file
# Completato il:  46.2 % dei file
# Completato il:  46.21 % dei file
# Completato il:  46.23 % dei file
# Completato il:  46.24 % dei file
# Completato il:  46.26 % dei file
# Completato il:  46.27 % dei file
# Completato il:  46.28 % dei file
# Completato il:  46.3 % dei file
# Completato il:  46.31 % dei file
# Completato il:  46.32 % dei file
# Completato il:  46.34 % dei file
# Completato il:  46.35 % dei file
# Completato il:  46.36 % dei file
# Completato il:  46.38 % dei file
# Completato il:  46.39 % dei file
# Completato il:  46.41 % dei file
# Completato il:  46.42 % dei file
# Completato il:  46.43 % dei file
# Completato il:  46.45 % dei file
# Completato il:  46.46 % dei file
# Completato il:  46.47 % dei file
# Completato il:  46.49 % dei file
# Completato il:  46.5 % dei file
# Completato il:  46.52 % dei file
# Completato il:  46.53 % dei file
# Completato il:  46.54 % dei file
# Completato il:  46.56 % dei file
# Completato il:  46.57 % dei file
# Completato il:  46.58 % dei file
# Completato il:  46.6 % dei file
# Completato il:  46.61 % dei file
# Completato il:  46.63 % dei file
# Completato il:  46.64 % dei file
# Completato il:  46.65 % dei file
# Completato il:  46.67 % dei file
# Completato il:  46.68 % dei file
# Completato il:  46.69 % dei file
# Completato il:  46.71 % dei file
# Completato il:  46.72 % dei file
# Completato il:  46.74 % dei file
# Completato il:  46.75 % dei file
# Completato il:  46.76 % dei file
# Completato il:  46.78 % dei file
# Completato il:  46.79 % dei file
# Completato il:  46.8 % dei file
# Completato il:  46.82 % dei file
# Completato il:  46.83 % dei file
# Completato il:  46.84 % dei file
# Completato il:  46.86 % dei file
# Completato il:  46.87 % dei file
# Completato il:  46.89 % dei file
# Completato il:  46.9 % dei file
# Completato il:  46.91 % dei file
# Completato il:  46.93 % dei file
# Completato il:  46.94 % dei file
# Completato il:  46.95 % dei file
# Completato il:  46.97 % dei file
# Completato il:  46.98 % dei file
# Completato il:  47.0 % dei file
# Completato il:  47.01 % dei file
# Completato il:  47.02 % dei file
# Completato il:  47.04 % dei file
# Completato il:  47.05 % dei file
# Completato il:  47.06 % dei file
# Completato il:  47.08 % dei file
# Completato il:  47.09 % dei file
# Completato il:  47.11 % dei file
# Completato il:  47.12 % dei file
# Completato il:  47.13 % dei file
# Completato il:  47.15 % dei file
# Completato il:  47.16 % dei file
# Completato il:  47.17 % dei file
# Completato il:  47.19 % dei file
# Completato il:  47.2 % dei file
# Completato il:  47.22 % dei file
# Completato il:  47.23 % dei file
# Completato il:  47.24 % dei file
# Completato il:  47.26 % dei file
# Completato il:  47.27 % dei file
# Completato il:  47.28 % dei file
# Completato il:  47.3 % dei file
# Completato il:  47.31 % dei file
# Completato il:  47.33 % dei file
# Completato il:  47.34 % dei file
# Completato il:  47.35 % dei file
# Completato il:  47.37 % dei file
# Completato il:  47.38 % dei file
# Completato il:  47.39 % dei file
# Completato il:  47.41 % dei file
# Completato il:  47.42 % dei file
# Completato il:  47.43 % dei file
# Completato il:  47.45 % dei file
# Completato il:  47.46 % dei file
# Completato il:  47.48 % dei file
# Completato il:  47.49 % dei file
# Completato il:  47.5 % dei file
# Completato il:  47.52 % dei file
# Completato il:  47.53 % dei file
# Completato il:  47.54 % dei file
# Completato il:  47.56 % dei file
# Completato il:  47.57 % dei file
# Completato il:  47.59 % dei file
# Completato il:  47.6 % dei file
# Completato il:  47.61 % dei file
# Completato il:  47.63 % dei file
# Completato il:  47.64 % dei file
# Completato il:  47.65 % dei file
# Completato il:  47.67 % dei file
# Completato il:  47.68 % dei file
# Completato il:  47.7 % dei file
# Completato il:  47.71 % dei file
# Completato il:  47.72 % dei file
# Completato il:  47.74 % dei file
# Completato il:  47.75 % dei file
# Completato il:  47.76 % dei file
# Completato il:  47.78 % dei file
# Completato il:  47.79 % dei file
# Completato il:  47.81 % dei file
# Completato il:  47.82 % dei file
# Completato il:  47.83 % dei file
# Completato il:  47.85 % dei file
# Completato il:  47.86 % dei file
# Completato il:  47.87 % dei file
# Completato il:  47.89 % dei file
# Completato il:  47.9 % dei file
# Completato il:  47.91 % dei file
# Completato il:  47.93 % dei file
# Completato il:  47.94 % dei file
# Completato il:  47.96 % dei file
# Completato il:  47.97 % dei file
# Completato il:  47.98 % dei file
# Completato il:  48.0 % dei file
# Completato il:  48.01 % dei file
# Completato il:  48.02 % dei file
# Completato il:  48.04 % dei file
# Completato il:  48.05 % dei file
# Completato il:  48.07 % dei file
# Completato il:  48.08 % dei file
# Completato il:  48.09 % dei file
# Completato il:  48.11 % dei file
# Completato il:  48.12 % dei file
# Completato il:  48.13 % dei file
# Completato il:  48.15 % dei file
# Completato il:  48.16 % dei file
# Completato il:  48.18 % dei file
# Completato il:  48.19 % dei file
# Completato il:  48.2 % dei file
# Completato il:  48.22 % dei file
# Completato il:  48.23 % dei file
# Completato il:  48.24 % dei file
# Completato il:  48.26 % dei file
# Completato il:  48.27 % dei file
# Completato il:  48.29 % dei file
# Completato il:  48.3 % dei file
# Completato il:  48.31 % dei file
# Completato il:  48.33 % dei file
# Completato il:  48.34 % dei file
# Completato il:  48.35 % dei file
# Completato il:  48.37 % dei file
# Completato il:  48.38 % dei file
# Completato il:  48.4 % dei file
# Completato il:  48.41 % dei file
# Completato il:  48.42 % dei file
# Completato il:  48.44 % dei file
# Completato il:  48.45 % dei file
# Completato il:  48.46 % dei file
# Completato il:  48.48 % dei file
# Completato il:  48.49 % dei file
# Completato il:  48.5 % dei file
# Completato il:  48.52 % dei file
# Completato il:  48.53 % dei file
# Completato il:  48.55 % dei file
# Completato il:  48.56 % dei file
# Completato il:  48.57 % dei file
# Completato il:  48.59 % dei file
# Completato il:  48.6 % dei file
# Completato il:  48.61 % dei file
# Completato il:  48.63 % dei file
# Completato il:  48.64 % dei file
# Completato il:  48.66 % dei file
# Completato il:  48.67 % dei file
# Completato il:  48.68 % dei file
# Completato il:  48.7 % dei file
# Completato il:  48.71 % dei file
# Completato il:  48.72 % dei file
# Completato il:  48.74 % dei file
# Completato il:  48.75 % dei file
# Completato il:  48.77 % dei file
# Completato il:  48.78 % dei file
# Completato il:  48.79 % dei file
# Completato il:  48.81 % dei file
# Completato il:  48.82 % dei file
# Completato il:  48.83 % dei file
# Completato il:  48.85 % dei file
# Completato il:  48.86 % dei file
# Completato il:  48.88 % dei file
# Completato il:  48.89 % dei file
# Completato il:  48.9 % dei file
# Completato il:  48.92 % dei file
# Completato il:  48.93 % dei file
# Completato il:  48.94 % dei file
# Completato il:  48.96 % dei file
# Completato il:  48.97 % dei file
# Completato il:  48.98 % dei file
# Completato il:  49.0 % dei file
# Completato il:  49.01 % dei file
# Completato il:  49.03 % dei file
# Completato il:  49.04 % dei file
# Completato il:  49.05 % dei file
# Completato il:  49.07 % dei file
# Completato il:  49.08 % dei file
# Completato il:  49.09 % dei file
# Completato il:  49.11 % dei file
# Completato il:  49.12 % dei file
# Completato il:  49.14 % dei file
# Completato il:  49.15 % dei file
# Completato il:  49.16 % dei file
# Completato il:  49.18 % dei file
# Completato il:  49.19 % dei file
# Completato il:  49.2 % dei file
# Completato il:  49.22 % dei file
# Completato il:  49.23 % dei file
# Completato il:  49.25 % dei file
# Completato il:  49.26 % dei file
# Completato il:  49.27 % dei file
# Completato il:  49.29 % dei file
# Completato il:  49.3 % dei file
# Completato il:  49.31 % dei file
# Completato il:  49.33 % dei file
# Completato il:  49.34 % dei file
# Completato il:  49.36 % dei file
# Completato il:  49.37 % dei file
# Completato il:  49.38 % dei file
# Completato il:  49.4 % dei file
# Completato il:  49.41 % dei file
# Completato il:  49.42 % dei file
# Completato il:  49.44 % dei file
# Completato il:  49.45 % dei file
# Completato il:  49.47 % dei file
# Completato il:  49.48 % dei file
# Completato il:  49.49 % dei file
# Completato il:  49.51 % dei file
# Completato il:  49.52 % dei file
# Completato il:  49.53 % dei file
# Completato il:  49.55 % dei file
# Completato il:  49.56 % dei file
# Completato il:  49.57 % dei file
# Completato il:  49.59 % dei file
# Completato il:  49.6 % dei file
# Completato il:  49.62 % dei file
# Completato il:  49.63 % dei file
# Completato il:  49.64 % dei file
# Completato il:  49.66 % dei file
# Completato il:  49.67 % dei file
# Completato il:  49.68 % dei file
# Completato il:  49.7 % dei file
# Completato il:  49.71 % dei file
# Completato il:  49.73 % dei file
# Completato il:  49.74 % dei file
# Completato il:  49.75 % dei file
# Completato il:  49.77 % dei file
# Completato il:  49.78 % dei file
# Completato il:  49.79 % dei file
# Completato il:  49.81 % dei file
# Completato il:  49.82 % dei file
# Completato il:  49.84 % dei file
# Completato il:  49.85 % dei file
# Completato il:  49.86 % dei file
# Completato il:  49.88 % dei file
# Completato il:  49.89 % dei file
# Completato il:  49.9 % dei file
# Completato il:  49.92 % dei file
# Completato il:  49.93 % dei file
# Completato il:  49.95 % dei file
# Completato il:  49.96 % dei file
# Completato il:  49.97 % dei file
# Completato il:  49.99 % dei file
# Completato il:  50.0 % dei file
# Completato il:  50.01 % dei file
# Completato il:  50.03 % dei file
# Completato il:  50.04 % dei file
# Completato il:  50.05 % dei file
# Completato il:  50.07 % dei file
# Completato il:  50.08 % dei file
# Completato il:  50.1 % dei file
# Completato il:  50.11 % dei file
# Completato il:  50.12 % dei file
# Completato il:  50.14 % dei file
# Completato il:  50.15 % dei file
# Completato il:  50.16 % dei file
# Completato il:  50.18 % dei file
# Completato il:  50.19 % dei file
# Completato il:  50.21 % dei file
# Completato il:  50.22 % dei file
# Completato il:  50.23 % dei file
# Completato il:  50.25 % dei file
# Completato il:  50.26 % dei file
# Completato il:  50.27 % dei file
# Completato il:  50.29 % dei file
# Completato il:  50.3 % dei file
# Completato il:  50.32 % dei file
# Completato il:  50.33 % dei file
# Completato il:  50.34 % dei file
# Completato il:  50.36 % dei file
# Completato il:  50.37 % dei file
# Completato il:  50.38 % dei file
# Completato il:  50.4 % dei file
# Completato il:  50.41 % dei file
# Completato il:  50.43 % dei file
# Completato il:  50.44 % dei file
# Completato il:  50.45 % dei file
# Completato il:  50.47 % dei file
# Completato il:  50.48 % dei file
# Completato il:  50.49 % dei file
# Completato il:  50.51 % dei file
# Completato il:  50.52 % dei file
# Completato il:  50.53 % dei file
# Completato il:  50.55 % dei file
# Completato il:  50.56 % dei file
# Completato il:  50.58 % dei file
# Completato il:  50.59 % dei file
# Completato il:  50.6 % dei file
# Completato il:  50.62 % dei file
# Completato il:  50.63 % dei file
# Completato il:  50.64 % dei file
# Completato il:  50.66 % dei file
# Completato il:  50.67 % dei file
# Completato il:  50.69 % dei file
# Completato il:  50.7 % dei file
# Completato il:  50.71 % dei file
# Completato il:  50.73 % dei file
# Completato il:  50.74 % dei file
# Completato il:  50.75 % dei file
# Completato il:  50.77 % dei file
# Completato il:  50.78 % dei file
# Completato il:  50.8 % dei file
# Completato il:  50.81 % dei file
# Completato il:  50.82 % dei file
# Completato il:  50.84 % dei file
# Completato il:  50.85 % dei file
# Completato il:  50.86 % dei file
# Completato il:  50.88 % dei file
# Completato il:  50.89 % dei file
# Completato il:  50.91 % dei file
# Completato il:  50.92 % dei file
# Completato il:  50.93 % dei file
# Completato il:  50.95 % dei file
# Completato il:  50.96 % dei file
# Completato il:  50.97 % dei file
# Completato il:  50.99 % dei file
# Completato il:  51.0 % dei file
# Completato il:  51.02 % dei file
# Completato il:  51.03 % dei file
# Completato il:  51.04 % dei file
# Completato il:  51.06 % dei file
# Completato il:  51.07 % dei file
# Completato il:  51.08 % dei file
# Completato il:  51.1 % dei file
# Completato il:  51.11 % dei file
# Completato il:  51.12 % dei file
# Completato il:  51.14 % dei file
# Completato il:  51.15 % dei file
# Completato il:  51.17 % dei file
# Completato il:  51.18 % dei file
# Completato il:  51.19 % dei file
# Completato il:  51.21 % dei file
# Completato il:  51.22 % dei file
# Completato il:  51.23 % dei file
# Completato il:  51.25 % dei file
# Completato il:  51.26 % dei file
# Completato il:  51.28 % dei file
# Completato il:  51.29 % dei file
# Completato il:  51.3 % dei file
# Completato il:  51.32 % dei file
# Completato il:  51.33 % dei file
# Completato il:  51.34 % dei file
# Completato il:  51.36 % dei file
# Completato il:  51.37 % dei file
# Completato il:  51.39 % dei file
# Completato il:  51.4 % dei file
# ...
# Completato il:  93.35 % dei file
# Completato il:  93.36 % dei file
# Completato il:  93.37 % dei file
# Completato il:  93.39 % dei file
# Completato il:  93.4 % dei file
# Completato il:  93.42 % dei file
# Completato il:  93.43 % dei file
# Completato il:  93.44 % dei file
# Completato il:  93.46 % dei file
# Completato il:  93.47 % dei file
# Completato il:  93.48 % dei file
# Completato il:  93.5 % dei file
# Completato il:  93.51 % dei file
# Completato il:  93.53 % dei file
# Completato il:  93.54 % dei file
# Completato il:  93.55 % dei file
# Completato il:  93.57 % dei file
# Completato il:  93.58 % dei file
# Completato il:  93.59 % dei file
# Completato il:  93.61 % dei file
# Completato il:  93.62 % dei file
# Completato il:  93.64 % dei file
# Completato il:  93.65 % dei file
# Completato il:  93.66 % dei file
# Completato il:  93.68 % dei file
# Completato il:  93.69 % dei file
# Completato il:  93.7 % dei file
# Completato il:  93.72 % dei file
# Completato il:  93.73 % dei file
# Completato il:  93.74 % dei file
# Completato il:  93.76 % dei file
# Completato il:  93.77 % dei file
# Completato il:  93.79 % dei file
# Completato il:  93.8 % dei file
# Completato il:  93.81 % dei file
# Completato il:  93.83 % dei file
# Completato il:  93.84 % dei file
# Completato il:  93.85 % dei file
# Completato il:  93.87 % dei file
# Completato il:  93.88 % dei file
# Completato il:  93.9 % dei file
# Completato il:  93.91 % dei file
# Completato il:  93.92 % dei file
# Completato il:  93.94 % dei file
# Completato il:  93.95 % dei file
# Completato il:  93.96 % dei file
# Completato il:  93.98 % dei file
# Completato il:  93.99 % dei file
# Completato il:  94.01 % dei file
# Completato il:  94.02 % dei file
# Completato il:  94.03 % dei file
# Completato il:  94.05 % dei file
# Completato il:  94.06 % dei file
# Completato il:  94.07 % dei file
# Completato il:  94.09 % dei file
# Completato il:  94.1 % dei file
# Completato il:  94.12 % dei file
# Completato il:  94.13 % dei file
# Completato il:  94.14 % dei file
# Completato il:  94.16 % dei file
# Completato il:  94.17 % dei file
# Completato il:  94.18 % dei file
# Completato il:  94.2 % dei file
# Completato il:  94.21 % dei file
# Completato il:  94.22 % dei file
# Completato il:  94.24 % dei file
# Completato il:  94.25 % dei file
# Completato il:  94.27 % dei file
# Completato il:  94.28 % dei file
# Completato il:  94.29 % dei file
# Completato il:  94.31 % dei file
# Completato il:  94.32 % dei file
# Completato il:  94.33 % dei file
# Completato il:  94.35 % dei file
# Completato il:  94.36 % dei file
# Completato il:  94.38 % dei file
# Completato il:  94.39 % dei file
# Completato il:  94.4 % dei file
# Completato il:  94.42 % dei file
# Completato il:  94.43 % dei file
# Completato il:  94.44 % dei file
# Completato il:  94.46 % dei file
# Completato il:  94.47 % dei file
# Completato il:  94.49 % dei file
# Completato il:  94.5 % dei file
# Completato il:  94.51 % dei file
# Completato il:  94.53 % dei file
# Completato il:  94.54 % dei file
# Completato il:  94.55 % dei file
# Completato il:  94.57 % dei file
# Completato il:  94.58 % dei file
# Completato il:  94.6 % dei file
# Completato il:  94.61 % dei file
# Completato il:  94.62 % dei file
# Completato il:  94.64 % dei file
# Completato il:  94.65 % dei file
# Completato il:  94.66 % dei file
# Completato il:  94.68 % dei file
# Completato il:  94.69 % dei file
# Completato il:  94.71 % dei file
# Completato il:  94.72 % dei file
# Completato il:  94.73 % dei file
# Completato il:  94.75 % dei file
# Completato il:  94.76 % dei file
# Completato il:  94.77 % dei file
# Completato il:  94.79 % dei file
# Completato il:  94.8 % dei file
# Completato il:  94.81 % dei file
# Completato il:  94.83 % dei file
# Completato il:  94.84 % dei file
# Completato il:  94.86 % dei file
# Completato il:  94.87 % dei file
# Completato il:  94.88 % dei file
# Completato il:  94.9 % dei file
# Completato il:  94.91 % dei file
# Completato il:  94.92 % dei file
# Completato il:  94.94 % dei file
# Completato il:  94.95 % dei file
# Completato il:  94.97 % dei file
# Completato il:  94.98 % dei file
# Completato il:  94.99 % dei file
# Completato il:  95.01 % dei file
# Completato il:  95.02 % dei file
# Completato il:  95.03 % dei file
# Completato il:  95.05 % dei file
# Completato il:  95.06 % dei file
# Completato il:  95.08 % dei file
# Completato il:  95.09 % dei file
# Completato il:  95.1 % dei file
# Completato il:  95.12 % dei file
# Completato il:  95.13 % dei file
# Completato il:  95.14 % dei file
# Completato il:  95.16 % dei file
# Completato il:  95.17 % dei file
# Completato il:  95.19 % dei file
# Completato il:  95.2 % dei file
# Completato il:  95.21 % dei file
# Completato il:  95.23 % dei file
# Completato il:  95.24 % dei file
# Completato il:  95.25 % dei file
# Completato il:  95.27 % dei file
# Completato il:  95.28 % dei file
# Completato il:  95.29 % dei file
# Completato il:  95.31 % dei file
# Completato il:  95.32 % dei file
# Completato il:  95.34 % dei file
# Completato il:  95.35 % dei file
# Completato il:  95.36 % dei file
# Completato il:  95.38 % dei file
# Completato il:  95.39 % dei file
# Completato il:  95.4 % dei file
# Completato il:  95.42 % dei file
# Completato il:  95.43 % dei file
# Completato il:  95.45 % dei file
# Completato il:  95.46 % dei file
# Completato il:  95.47 % dei file
# Completato il:  95.49 % dei file
# Completato il:  95.5 % dei file
# Completato il:  95.51 % dei file
# Completato il:  95.53 % dei file
# Completato il:  95.54 % dei file
# Completato il:  95.56 % dei file
# Completato il:  95.57 % dei file
# Completato il:  95.58 % dei file
# Completato il:  95.6 % dei file
# Completato il:  95.61 % dei file
# Completato il:  95.62 % dei file
# Completato il:  95.64 % dei file
# Completato il:  95.65 % dei file
# Completato il:  95.67 % dei file
# Completato il:  95.68 % dei file
# Completato il:  95.69 % dei file
# Completato il:  95.71 % dei file
# Completato il:  95.72 % dei file
# Completato il:  95.73 % dei file
# Completato il:  95.75 % dei file
# Completato il:  95.76 % dei file
# Completato il:  95.78 % dei file
# Completato il:  95.79 % dei file
# Completato il:  95.8 % dei file
# Completato il:  95.82 % dei file
# Completato il:  95.83 % dei file
# Completato il:  95.84 % dei file
# Completato il:  95.86 % dei file
# Completato il:  95.87 % dei file
# Completato il:  95.88 % dei file
# Completato il:  95.9 % dei file
# Completato il:  95.91 % dei file
# Completato il:  95.93 % dei file
# Completato il:  95.94 % dei file
# Completato il:  95.95 % dei file
# Completato il:  95.97 % dei file
# Completato il:  95.98 % dei file
# Completato il:  95.99 % dei file
# Completato il:  96.01 % dei file
# Completato il:  96.02 % dei file
# Completato il:  96.04 % dei file
# Completato il:  96.05 % dei file
# Completato il:  96.06 % dei file
# Completato il:  96.08 % dei file
# Completato il:  96.09 % dei file
# Completato il:  96.1 % dei file
# Completato il:  96.12 % dei file
# Completato il:  96.13 % dei file
# Completato il:  96.15 % dei file
# Completato il:  96.16 % dei file
# Completato il:  96.17 % dei file
# Completato il:  96.19 % dei file
# Completato il:  96.2 % dei file
# Completato il:  96.21 % dei file
# Completato il:  96.23 % dei file
# Completato il:  96.24 % dei file
# Completato il:  96.26 % dei file
# Completato il:  96.27 % dei file
# Completato il:  96.28 % dei file
# Completato il:  96.3 % dei file
# Completato il:  96.31 % dei file
# Completato il:  96.32 % dei file
# Completato il:  96.34 % dei file
# Completato il:  96.35 % dei file
# Completato il:  96.36 % dei file
# Completato il:  96.38 % dei file
# Completato il:  96.39 % dei file
# Completato il:  96.41 % dei file
# Completato il:  96.42 % dei file
# Completato il:  96.43 % dei file
# Completato il:  96.45 % dei file
# Completato il:  96.46 % dei file
# Completato il:  96.47 % dei file
# Completato il:  96.49 % dei file
# Completato il:  96.5 % dei file
# Completato il:  96.52 % dei file
# Completato il:  96.53 % dei file
# Completato il:  96.54 % dei file
# Completato il:  96.56 % dei file
# Completato il:  96.57 % dei file
# Completato il:  96.58 % dei file
# Completato il:  96.6 % dei file
# Completato il:  96.61 % dei file
# Completato il:  96.63 % dei file
# Completato il:  96.64 % dei file
# Completato il:  96.65 % dei file
# Completato il:  96.67 % dei file
# Completato il:  96.68 % dei file
# Completato il:  96.69 % dei file
# Completato il:  96.71 % dei file
# Completato il:  96.72 % dei file
# Completato il:  96.74 % dei file
# Completato il:  96.75 % dei file
# Completato il:  96.76 % dei file
# Completato il:  96.78 % dei file
# Completato il:  96.79 % dei file
# Completato il:  96.8 % dei file
# Completato il:  96.82 % dei file
# Completato il:  96.83 % dei file
# Completato il:  96.84 % dei file
# Completato il:  96.86 % dei file
# Completato il:  96.87 % dei file
# Completato il:  96.89 % dei file
# Completato il:  96.9 % dei file
# Completato il:  96.91 % dei file
# Completato il:  96.93 % dei file
# Completato il:  96.94 % dei file
# Completato il:  96.95 % dei file
# Completato il:  96.97 % dei file
# Completato il:  96.98 % dei file
# Completato il:  97.0 % dei file
# Completato il:  97.01 % dei file
# Completato il:  97.02 % dei file
# Completato il:  97.04 % dei file
# Completato il:  97.05 % dei file
# Completato il:  97.06 % dei file
# Completato il:  97.08 % dei file
# Completato il:  97.09 % dei file
# Completato il:  97.11 % dei file
# Completato il:  97.12 % dei file
# Completato il:  97.13 % dei file
# Completato il:  97.15 % dei file
# Completato il:  97.16 % dei file
# Completato il:  97.17 % dei file
# Completato il:  97.19 % dei file
# Completato il:  97.2 % dei file
# Completato il:  97.22 % dei file
# Completato il:  97.23 % dei file
# Completato il:  97.24 % dei file
# Completato il:  97.26 % dei file
# Completato il:  97.27 % dei file
# Completato il:  97.28 % dei file
# Completato il:  97.3 % dei file
# Completato il:  97.31 % dei file
# Completato il:  97.33 % dei file
# Completato il:  97.34 % dei file
# Completato il:  97.35 % dei file
# Completato il:  97.37 % dei file
# Completato il:  97.38 % dei file
# Completato il:  97.39 % dei file
# Completato il:  97.41 % dei file
# Completato il:  97.42 % dei file
# Completato il:  97.43 % dei file
# Completato il:  97.45 % dei file
# Completato il:  97.46 % dei file
# Completato il:  97.48 % dei file
# Completato il:  97.49 % dei file
# Completato il:  97.5 % dei file
# Completato il:  97.52 % dei file
# Completato il:  97.53 % dei file
# Completato il:  97.54 % dei file
# Completato il:  97.56 % dei file
# Completato il:  97.57 % dei file
# Completato il:  97.59 % dei file
# Completato il:  97.6 % dei file
# Completato il:  97.61 % dei file
# Completato il:  97.63 % dei file
# Completato il:  97.64 % dei file
# Completato il:  97.65 % dei file
# Completato il:  97.67 % dei file
# Completato il:  97.68 % dei file
# Completato il:  97.7 % dei file
# Completato il:  97.71 % dei file
# Completato il:  97.72 % dei file
# Completato il:  97.74 % dei file
# Completato il:  97.75 % dei file
# Completato il:  97.76 % dei file
# Completato il:  97.78 % dei file
# Completato il:  97.79 % dei file
# Completato il:  97.81 % dei file
# Completato il:  97.82 % dei file
# Completato il:  97.83 % dei file
# Completato il:  97.85 % dei file
# Completato il:  97.86 % dei file
# Completato il:  97.87 % dei file
# Completato il:  97.89 % dei file
# Completato il:  97.9 % dei file
# Completato il:  97.91 % dei file
# Completato il:  97.93 % dei file
# Completato il:  97.94 % dei file
# Completato il:  97.96 % dei file
# Completato il:  97.97 % dei file
# Completato il:  97.98 % dei file
# Completato il:  98.0 % dei file
# Completato il:  98.01 % dei file
# Completato il:  98.02 % dei file
# Completato il:  98.04 % dei file
# Completato il:  98.05 % dei file
# Completato il:  98.07 % dei file
# Completato il:  98.08 % dei file
# Completato il:  98.09 % dei file
# Completato il:  98.11 % dei file
# Completato il:  98.12 % dei file
# Completato il:  98.13 % dei file
# Completato il:  98.15 % dei file
# Completato il:  98.16 % dei file
# Completato il:  98.18 % dei file
# Completato il:  98.19 % dei file
# Completato il:  98.2 % dei file
# Completato il:  98.22 % dei file
# Completato il:  98.23 % dei file
# Completato il:  98.24 % dei file
# Completato il:  98.26 % dei file
# Completato il:  98.27 % dei file
# Completato il:  98.29 % dei file
# Completato il:  98.3 % dei file
# Completato il:  98.31 % dei file
# Completato il:  98.33 % dei file
# Completato il:  98.34 % dei file
# Completato il:  98.35 % dei file
# Completato il:  98.37 % dei file
# Completato il:  98.38 % dei file
# Completato il:  98.4 % dei file
# Completato il:  98.41 % dei file
# Completato il:  98.42 % dei file
# Completato il:  98.44 % dei file
# Completato il:  98.45 % dei file
# Completato il:  98.46 % dei file
# Completato il:  98.48 % dei file
# Completato il:  98.49 % dei file
# Completato il:  98.5 % dei file
# Completato il:  98.52 % dei file
# Completato il:  98.53 % dei file
# Completato il:  98.55 % dei file
# Completato il:  98.56 % dei file
# Completato il:  98.57 % dei file
# Completato il:  98.59 % dei file
# Completato il:  98.6 % dei file
# Completato il:  98.61 % dei file
# Completato il:  98.63 % dei file
# Completato il:  98.64 % dei file
# Completato il:  98.66 % dei file
# Completato il:  98.67 % dei file
# Completato il:  98.68 % dei file
# Completato il:  98.7 % dei file
# Completato il:  98.71 % dei file
# Completato il:  98.72 % dei file
# Completato il:  98.74 % dei file
# Completato il:  98.75 % dei file
# Completato il:  98.77 % dei file
# Completato il:  98.78 % dei file
# Completato il:  98.79 % dei file
# Completato il:  98.81 % dei file
# Completato il:  98.82 % dei file
# Completato il:  98.83 % dei file
# Completato il:  98.85 % dei file
# Completato il:  98.86 % dei file
# Completato il:  98.88 % dei file
# Completato il:  98.89 % dei file
# Completato il:  98.9 % dei file
# Completato il:  98.92 % dei file
# Completato il:  98.93 % dei file
# Completato il:  98.94 % dei file
# Completato il:  98.96 % dei file
# Completato il:  98.97 % dei file
# Completato il:  98.98 % dei file
# Completato il:  99.0 % dei file
# Completato il:  99.01 % dei file
# Completato il:  99.03 % dei file
# Completato il:  99.04 % dei file
# Completato il:  99.05 % dei file
# Completato il:  99.07 % dei file
# Completato il:  99.08 % dei file
# Completato il:  99.09 % dei file
# Completato il:  99.11 % dei file
# Completato il:  99.12 % dei file
# Completato il:  99.14 % dei file
# Completato il:  99.15 % dei file
# Completato il:  99.16 % dei file
# Completato il:  99.18 % dei file
# Completato il:  99.19 % dei file
# Completato il:  99.2 % dei file
# Completato il:  99.22 % dei file
# Completato il:  99.23 % dei file
# Completato il:  99.25 % dei file
# Completato il:  99.26 % dei file
# Completato il:  99.27 % dei file
# Completato il:  99.29 % dei file
# Completato il:  99.3 % dei file
# Completato il:  99.31 % dei file
# Completato il:  99.33 % dei file
# Completato il:  99.34 % dei file
# Completato il:  99.36 % dei file
# Completato il:  99.37 % dei file
# Completato il:  99.38 % dei file
# Completato il:  99.4 % dei file
# Completato il:  99.41 % dei file
# Completato il:  99.42 % dei file
# Completato il:  99.44 % dei file
# Completato il:  99.45 % dei file
# Completato il:  99.47 % dei file
# Completato il:  99.48 % dei file
# Completato il:  99.49 % dei file
# Completato il:  99.51 % dei file
# Completato il:  99.52 % dei file
# Completato il:  99.53 % dei file
# Completato il:  99.55 % dei file
# Completato il:  99.56 % dei file
# Completato il:  99.57 % dei file
# Completato il:  99.59 % dei file
# Completato il:  99.6 % dei file
# Completato il:  99.62 % dei file
# Completato il:  99.63 % dei file
# Completato il:  99.64 % dei file
# Completato il:  99.66 % dei file
# Completato il:  99.67 % dei file
# Completato il:  99.68 % dei file
# Completato il:  99.7 % dei file
# Completato il:  99.71 % dei file
# Completato il:  99.73 % dei file
# Completato il:  99.74 % dei file
# Completato il:  99.75 % dei file
# Completato il:  99.77 % dei file
# Completato il:  99.78 % dei file
# Completato il:  99.79 % dei file
# Completato il:  99.81 % dei file
# Completato il:  99.82 % dei file
# Completato il:  99.84 % dei file
# Completato il:  99.85 % dei file
# Completato il:  99.86 % dei file
# Completato il:  99.88 % dei file
# Completato il:  99.89 % dei file
# Completato il:  99.9 % dei file
# Completato il:  99.92 % dei file
# Completato il:  99.93 % dei file
# Completato il:  99.95 % dei file
# Completato il:  99.96 % dei file
# Completato il:  99.97 % dei file
# Completato il:  99.99 % dei file
# Completato il:  100.0 % dei file

# %% [markdown]
# ## Split train-validation-test
#
# Per utilizzare il metodo *flow_from_directory* di keras è necessario che i file vengano divisi in sottocartelle, ognuna contentente le due classi distinte. Di seguito abbiamo utilizzato la libreria *splitfolders* per eseguire questa operazione velocemente ed efficientemente.

# %%
# !pip install split-folders
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.6/dist-packages (0.4.3)

# %%
import splitfolders
splitfolders.ratio("gdrive/MyDrive/emergency_models", output="gdrive/MyDrive/emergency_true_models", ratio=(0.6, 0.3, 0.1))
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:00,  1.31 files/s]
# Copying files: 12 files [00:00,  1.86 files/s]
# Copying files: 23 files [00:01,  2.60 files/s]
# Copying files: 32 files [00:01,  3.57 files/s]
# Copying files: 48 files [00:01,  5.01 files/s]
# Copying files: 62 files [00:01,  7.05 files/s]
# Copying files: 70 files [00:01,  9.60 files/s]
# Copying files: 83 files [00:02, 13.02 files/s]
# Copying files: 98 files [00:02, 17.93 files/s]
# Copying files: 108 files [00:02, 22.99 files/s]
# Copying files: 117 files [00:02, 28.04 files/s]
# Copying files: 133 files [00:02, 37.25 files/s]
# Copying files: 144 files [00:02, 43.07 files/s]
# Copying files: 154 files [00:02, 46.30 files/s]
# Copying files: 165 files [00:03, 50.51 files/s]
# Copying files: 179 files [00:03, 62.41 files/s]
# Copying files: 189 files [00:03, 64.55 files/s]
# Copying files: 198 files [00:03, 61.00 files/s]
# Copying files: 211 files [00:03, 63.91 files/s]
# Copying files: 226 files [00:03, 77.16 files/s]
# Copying files: 236 files [00:03, 72.05 files/s]
# Copying files: 245 files [00:04, 66.71 files/s]
# Copying files: 258 files [00:04, 68.68 files/s]
# Copying files: 272 files [00:04, 80.92 files/s]
# Copying files: 282 files [00:04, 74.53 files/s]
# Copying files: 291 files [00:04, 67.28 files/s]
# Copying files: 304 files [00:04, 68.76 files/s]
# Copying files: 319 files [00:05, 70.61 files/s]
# Copying files: 334 files [00:05, 83.44 files/s]
# Copying files: 344 files [00:05, 77.10 files/s]
# Copying files: 353 files [00:05, 67.98 files/s]
# Copying files: 366 files [00:05, 69.53 files/s]
# Copying files: 381 files [00:05, 71.21 files/s]
# Copying files: 393 files [00:06, 80.59 files/s]
# Copying files: 402 files [00:06, 74.01 files/s]
# Copying files: 411 files [00:06, 68.90 files/s]
# Copying files: 426 files [00:06, 82.05 files/s]
# Copying files: 6491 files [01:28, 72.86 files/s]
# Copying files: 6505 files [01:28, 84.58 files/s]
# Copying files: 6515 files [01:29, 78.12 files/s]
# Copying files: 6524 files [01:29, 70.94 files/s]
# Copying files: 6538 files [01:29, 82.94 files/s]
# Copying files: 6548 files [01:29, 77.45 files/s]
# Copying files: 6557 files [01:29, 71.05 files/s]
# Copying files: 6570 files [01:29, 70.44 files/s]
# Copying files: 6584 files [01:30, 73.15 files/s]

# %% [markdown]
# # Reti neurali
#
# Si definiscono ora le diverse tipologie di reti che sono state utilizzate

# %% [markdown]
# ## XCEPTION
#
# La prima rete utilizzata è la **xception**.

# %% [markdown]
# Qui di seguito viene definita la funzione *acc_loss* utilizzata per meglio visualizzare i risultati dell'addestramento delle reti.

# %% [markdown]
# ### Generator
#
# Il **train_generator** viene definito con le stesse operazione di preprocessing utilizzate dalla Xception. Ulteriori opzioni definite sono la *batch_size* uguale a 32 e lo *shuffle* viene settato a True.
#
# Non sono state definite operazioni di *data augmentation* in quanto il dataset di immagini che è stato utilizzato presentava già operazioni di augmentation.

# %%
train_processing = keras.preprocessing.image.ImageDataGenerator(preprocessing_function = xception.preprocess_input)

train_generator = train_processing.flow_from_directory("gdrive/MyDrive/emergency_true_models/train",
                                    target_size = (224, 224),
                                    color_mode = "rgb",
                                    batch_size = 32,
                                    class_mode = "categorical",
                                    shuffle = True,
                                    seed = 1)
# Out:
# Found 3950 images belonging to 2 classes.

# %% [markdown]
# Vengono definiti **validation_generator** e **test_generator**.

# %%
validation_processing = keras.preprocessing.image.ImageDataGenerator(preprocessing_function= xception.preprocess_input)

validation_generator = validation_processing.flow_from_directory("gdrive/MyDrive/emergency_true_models/val",
                                    target_size = (224, 224),
                                    color_mode = "rgb",
                                    batch_size = 32,
                                    class_mode = "categorical",
                                    shuffle = False,
                                    seed = 1)
# Out:
# Found 1975 images belonging to 2 classes.

# %%
test_processing = keras.preprocessing.image.ImageDataGenerator(preprocessing_function= xception.preprocess_input)

test_generator = test_processing.flow_from_directory("gdrive/MyDrive/emergency_true_models/test",
                                    target_size = (224, 224),
                                    color_mode = "rgb",
                                    batch_size = 32,
                                    class_mode = "categorical",
                                    shuffle = False,
                                    seed = 1)
# Out:
# Found 659 images belonging to 2 classes.

# %% [markdown]
#  ### Definizione della rete
#
#  Viene importata la rete senza includere l'ultimo layer, in quanto sarà necessario adattarlo alle nostre esigenze, ovvero l'output desiderato.

# %%
base_net = xception.Xception(input_shape = (224,224,3),
                        weights = 'imagenet',
                        include_top = False,
                        pooling = 'avg')

# %% [markdown]
# Vengono congelati i layer della rete, in quanto la rete è stata preaddestrata, gli unici pesi che andranno a modificarsi saranno quelli corrispondenti ai layer aggiunti.

# %%
for layer in base_net.layers:
    layer.trainable = False

# %% [markdown]
# Si aggiungono due layer, entrambi **dense**, il primo con attivazione **RELU** e il secondo con attivazione **sigmoid**. Ovviamente, avendo solo due classi da predire, l'ultimo layer presenta solo due neuroni.

# %%
x = base_net.output

x = keras.layers.Dense(64, activation = "relu") (x)
pred = keras.layers.Dense(2, activation = 'softmax') (x)

# %%
net1 = keras.Model(inputs = base_net.input, outputs = pred)

# %%
net1.compile(loss = keras.losses.categorical_crossentropy,
           optimizer = keras.optimizers.Adam(),
           metrics = ['accuracy'])

hist1 = net1.fit(train_generator,
       epochs = 20,
       batch_size = 32,
       validation_data = validation_generator)
# Out:
# Epoch 1/20
# 124/124 [==============================] - 98s 765ms/step - loss: 0.3001 - accuracy: 0.8662 - val_loss: 0.1859 - val_accuracy: 0.9266
# Epoch 2/20
# 124/124 [==============================] - 23s 188ms/step - loss: 0.1570 - accuracy: 0.9358 - val_loss: 0.1670 - val_accuracy: 0.9291
# Epoch 3/20
# 124/124 [==============================] - 23s 189ms/step - loss: 0.1524 - accuracy: 0.9342 - val_loss: 0.1674 - val_accuracy: 0.9332
# Epoch 4/20
# 124/124 [==============================] - 23s 187ms/step - loss: 0.1254 - accuracy: 0.9536 - val_loss: 0.1555 - val_accuracy: 0.9327
# Epoch 5/20
# 124/124 [==============================] - 23s 187ms/step - loss: 0.1110 - accuracy: 0.9565 - val_loss: 0.1717 - val_accuracy: 0.9347
# Epoch 6/20
# 124/124 [==============================] - 24s 194ms/step - loss: 0.0889 - accuracy: 0.9659 - val_loss: 0.1627 - val_accuracy: 0.9342
# Epoch 7/20
# 124/124 [==============================] - 23s 188ms/step - loss: 0.0673 - accuracy: 0.9816 - val_loss: 0.1558 - val_accuracy: 0.9413
# Epoch 8/20
# 124/124 [==============================] - 23s 187ms/step - loss: 0.0601 - accuracy: 0.9766 - val_loss: 0.1663 - val_accuracy: 0.9387
# Epoch 9/20
# 124/124 [==============================] - 23s 186ms/step - loss: 0.0511 - accuracy: 0.9869 - val_loss: 0.1675 - val_accuracy: 0.9403
# Epoch 10/20
# 124/124 [==============================] - 24s 190ms/step - loss: 0.0356 - accuracy: 0.9882 - val_loss: 0.1618 - val_accuracy: 0.9423
# Epoch 11/20
# 124/124 [==============================] - 23s 187ms/step - loss: 0.0306 - accuracy: 0.9949 - val_loss: 0.1739 - val_accuracy: 0.9408
# Epoch 12/20
# 124/124 [==============================] - 23s 186ms/step - loss: 0.0302 - accuracy: 0.9908 - val_loss: 0.1803 - val_accuracy: 0.9382
# Epoch 13/20
# 124/124 [==============================] - 23s 188ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.2080 - val_accuracy: 0.9367
# Epoch 14/20
# 124/124 [==============================] - 23s 187ms/step - loss: 0.0150 - accuracy: 0.9976 - val_loss: 0.1899 - val_accuracy: 0.9413
# Epoch 15/20
# 124/124 [==============================] - 23s 186ms/step - loss: 0.0116 - accuracy: 0.9981 - val_loss: 0.2161 - val_accuracy: 0.9443
# Epoch 16/20
# 124/124 [==============================] - 23s 187ms/step - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.2086 - val_accuracy: 0.9463
# Epoch 17/20
# 124/124 [==============================] - 23s 188ms/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 0.1989 - val_accuracy: 0.9478
# Epoch 18/20
# 124/124 [==============================] - 23s 186ms/step - loss: 0.0069 - accuracy: 0.9990 - val_loss: 0.2493 - val_accuracy: 0.9357
# Epoch 19/20
# 124/124 [==============================] - 24s 194ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.2147 - val_accuracy: 0.9433
# Epoch 20/20
# 124/124 [==============================] - 23s 188ms/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 0.2465 - val_accuracy: 0.9347

# %% [markdown]
# Si procede all'addestramento della rete.

# %%
fig = plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(hist1.history['loss'], label = "Train loss", color = "#416685")
plt.plot(hist1.history['val_loss'], label="Validation loss", color = "#E88920")
plt.legend(loc='upper right', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Epochs', size = 15)
plt.ylabel('Loss', size = 15) 

plt.subplot(1,2,2)
plt.plot(hist1.history['accuracy'], label = "Train accuracy", color = "#416685")
plt.plot(hist1.history['val_accuracy'], label="Validation accuracy", color = "#E88920")
plt.legend(loc='upper right', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Epochs', size = 15)
plt.ylabel('Accuracy', size = 15) 
fig.savefig("loss_accuracy_xception.png", dpi = 300)

# %%
acc1 = net1.evaluate(test_generator)
# Out:
# 21/21 [==============================] - 163s 8s/step - loss: 0.1746 - accuracy: 0.9560

# %% [markdown]
# Calcoliamo ora i risultati per visalizzare la matrice di confusione e meglio capire i risultati.

# %%
pred_1 = net1.predict(test_generator)

# %%
pred_1 = np.argmax(pred_1, axis = 1)

# %%
print(classification_report(test_generator.classes, pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       386
#            1       0.97      0.93      0.95       273
#
#     accuracy                           0.96       659
#    macro avg       0.96      0.95      0.95       659
# weighted avg       0.96      0.96      0.96       659

# %%
cm = confusion_matrix(test_generator.classes, pred_1)

fig = plt.figure(figsize = (6,6))
ax = plt.subplot()
sns.heatmap(cm, annot=True, annot_kws={"size": 16},
           linewidths=.1, cmap="YlGnBu")
plt.xlabel("True Class", size = 15)
plt.ylabel("Predicted Class", size = 15)
plt.xticks(size = 12)
plt.yticks(size = 12)
ax.yaxis.set_ticklabels(['Non Emergency', 'Emergency']) 
ax.xaxis.set_ticklabels(['Non Emergency', 'Emergency']) 

plt.title("Confusion matrix", size = 20)
fig.savefig("confusion_matrix_xception.png", dpi = 200)

# %%
net1.save('gdrive/MyDrive/modello_immagini')
# Out:
# INFO:tensorflow:Assets written to: gdrive/MyDrive/modello_immagini/assets

# %% [markdown]
# ## CNN
#
# Viene ora definita una rete convoluzionale e si procede all'addestramento.

# %%
model = keras.Sequential(
    [
     keras.Input(shape = (224,224,3)),
     layers.Conv2D(16, kernel_size = (3,3), activation = 'relu'),
     layers.MaxPooling2D(pool_size = (2,2)),
     layers.Conv2D(16, kernel_size = (3,3), activation = 'relu'),
     layers.MaxPooling2D(pool_size = (2,2)),
     layers.Flatten(),
     layers.Dense(124, activation = "relu"),
     layers.Dropout(0.5),
     layers.Dense(2, activation = 'softmax')
    ]
)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 109, 109, 16)      2320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 16)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 46656)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 124)               5785468
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 124)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 250
# =================================================================
# Total params: 5,788,486
# Trainable params: 5,788,486
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = "categorical_crossentropy",
              optimizer = keras.optimizers.Adam(),
              metrics = ["accuracy"])

histo_best = model.fit(train_generator, 
                       epochs = 20, 
                       batch_size = 32, 
                       validation_data = validation_generator)
# Out:
# Epoch 1/20
# 124/124 [==============================] - 22s 179ms/step - loss: 1.2323 - accuracy: 0.6265 - val_loss: 0.5713 - val_accuracy: 0.7129
# Epoch 2/20
# 124/124 [==============================] - 22s 174ms/step - loss: 0.5057 - accuracy: 0.7544 - val_loss: 0.5493 - val_accuracy: 0.7210
# Epoch 3/20
# 124/124 [==============================] - 21s 173ms/step - loss: 0.4137 - accuracy: 0.8236 - val_loss: 0.5164 - val_accuracy: 0.7646
# Epoch 4/20
# 124/124 [==============================] - 21s 173ms/step - loss: 0.3075 - accuracy: 0.8753 - val_loss: 0.5573 - val_accuracy: 0.7747
# Epoch 5/20
# 124/124 [==============================] - 22s 175ms/step - loss: 0.1976 - accuracy: 0.9249 - val_loss: 0.5875 - val_accuracy: 0.7686
# Epoch 6/20
# 124/124 [==============================] - 22s 175ms/step - loss: 0.1449 - accuracy: 0.9504 - val_loss: 0.7370 - val_accuracy: 0.7565
# Epoch 7/20
# 124/124 [==============================] - 21s 173ms/step - loss: 0.1115 - accuracy: 0.9627 - val_loss: 0.8191 - val_accuracy: 0.7646
# Epoch 8/20
# 124/124 [==============================] - 21s 172ms/step - loss: 0.0742 - accuracy: 0.9764 - val_loss: 0.8914 - val_accuracy: 0.7367
# Epoch 9/20
# 124/124 [==============================] - 21s 172ms/step - loss: 0.0874 - accuracy: 0.9726 - val_loss: 0.9553 - val_accuracy: 0.7504
# Epoch 10/20
# 124/124 [==============================] - 21s 171ms/step - loss: 0.0508 - accuracy: 0.9813 - val_loss: 1.0851 - val_accuracy: 0.7595
# Epoch 11/20
# 124/124 [==============================] - 21s 173ms/step - loss: 0.0477 - accuracy: 0.9839 - val_loss: 1.0520 - val_accuracy: 0.7590
# Epoch 12/20
# 124/124 [==============================] - 22s 174ms/step - loss: 0.0378 - accuracy: 0.9833 - val_loss: 1.2497 - val_accuracy: 0.7595
# Epoch 13/20
# 124/124 [==============================] - 21s 171ms/step - loss: 0.0429 - accuracy: 0.9841 - val_loss: 0.9204 - val_accuracy: 0.7570
# Epoch 14/20
# 124/124 [==============================] - 22s 176ms/step - loss: 0.0408 - accuracy: 0.9872 - val_loss: 1.2100 - val_accuracy: 0.7585
# Epoch 15/20
# 124/124 [==============================] - 21s 173ms/step - loss: 0.0400 - accuracy: 0.9852 - val_loss: 1.0658 - val_accuracy: 0.7635
# Epoch 16/20
# 124/124 [==============================] - 21s 172ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 1.1949 - val_accuracy: 0.7575
# Epoch 17/20
# 124/124 [==============================] - 21s 172ms/step - loss: 0.0336 - accuracy: 0.9877 - val_loss: 1.3158 - val_accuracy: 0.7600
# Epoch 18/20
# 124/124 [==============================] - 21s 174ms/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 1.2193 - val_accuracy: 0.7615
# Epoch 19/20
# 124/124 [==============================] - 21s 174ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.1918 - val_accuracy: 0.7671
# Epoch 20/20
# 124/124 [==============================] - 21s 170ms/step - loss: 0.0220 - accuracy: 0.9923 - val_loss: 1.4144 - val_accuracy: 0.7397

# %%
fig = plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(histo_best.history['loss'], label = "Train loss", color = "#416685")
plt.plot(histo_best.history['val_loss'], label="Validation loss", color = "#E88920")
plt.legend(loc='upper right', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Epochs', size = 15)
plt.ylabel('Loss', size = 15) 

plt.subplot(1,2,2)
plt.plot(histo_best.history['accuracy'], label = "Train accuracy", color = "#416685")
plt.plot(histo_best.history['val_accuracy'], label="Validation accuracy", color = "#E88920")
plt.legend(loc='upper right', fontsize = 12)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('Epochs', size = 15)
plt.ylabel('Accuracy', size = 15) 
fig.savefig("loss_accuracy_cnn.png", dpi = 300)

# %%
acc_best = model.evaluate(test_generator)
# Out:
# 21/21 [==============================] - 2s 111ms/step - loss: 1.4262 - accuracy: 0.7481

# %% [markdown]
# Come precedentemente si calcolano le previsioni per visualizzare la matrice di confusione.

# %%
yc_pred = model.predict(test_generator)
y_pred_best = np.argmax(yc_pred, axis = 1)

# %%
print(classification_report(test_generator.classes, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       386
#            1       0.68      0.75      0.71       273
#
#     accuracy                           0.75       659
#    macro avg       0.74      0.75      0.74       659
# weighted avg       0.75      0.75      0.75       659

# %%
cm = confusion_matrix(test_generator.classes, y_pred_best)
fig = plt.figure(figsize = (6,6))
ax = plt.subplot()
sns.heatmap(cm, annot=True, annot_kws={"size": 16},
           linewidths=.1, cmap="YlGnBu")
plt.xlabel("True Class", size = 15)
plt.ylabel("Predicted Class", size = 15)
plt.xticks(size = 12)
plt.yticks(size = 12)
ax.yaxis.set_ticklabels(['Non Emergency', 'Emergency']) 
ax.xaxis.set_ticklabels(['Non Emergency', 'Emergency']) 

plt.title("Confusion matrix", size = 20)
fig.savefig("confusion_matrix_cnn_scratch.png", dpi = 200)

# %% [markdown]
# # Demo
#
# Per effettuare una demo viene definito un generator:

# %%
single_processing = keras.preprocessing.image.ImageDataGenerator(preprocessing_function= xception.preprocess_input)

single_generator = single_processing.flow_from_directory("gdrive/MyDrive/single",
                                    target_size = (224, 224),
                                    color_mode = "rgb",
                                    batch_size = 13,
                                    class_mode = "categorical",
                                    shuffle = False,
                                    seed = 1)

test,label_test = next(single_generator)
# Out:
# Found 13 images belonging to 1 classes.

# %% [markdown]
# Viene caricato il modello salvato precedentemente:

# %%
net_finale = tf.keras.models.load_model('gdrive/MyDrive/modello_immagini')

# %% [markdown]
# Si producono le previsioni:

# %%
prova_pred = net_finale.predict(single_generator)
result = np.argmax(prova_pred, axis = 1)
result
# Out:
# array([1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 0, 1, 1])

# %%
labels = (train_generator.class_indices).copy()
labels['Not Emergency'] = labels['class_0']
labels['Emergency'] = labels['class_1']

del labels['class_0']
del labels['class_1']

labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in result]

# %%
predictions
# Out:
# ['Emergency',
#  'Emergency',
#  'Emergency',
#  'Not Emergency',
#  'Emergency',
#  'Emergency',
#  'Emergency',
#  'Emergency',
#  'Not Emergency',
#  'Not Emergency',
#  'Not Emergency',
#  'Emergency',
#  'Emergency']

# %% [markdown]
# La classe 1 è quella dei veicoli di emergenza

# %%
prova_pred
# Out:
# array([[8.6840219e-13, 1.0000000e+00],
#        [6.6370603e-07, 9.9999928e-01],
#        [9.9034969e-07, 9.9999905e-01],
#        [9.9946362e-01, 5.3644949e-04],
#        [9.2957231e-07, 9.9999905e-01],
#        [2.5742187e-04, 9.9974257e-01],
#        [5.9375678e-05, 9.9994063e-01],
#        [2.1418979e-04, 9.9978584e-01],
#        [9.8686045e-01, 1.3139535e-02],
#        [9.9973279e-01, 2.6715733e-04],
#        [9.9999940e-01, 6.1370611e-07],
#        [2.9033453e-03, 9.9709666e-01],
#        [1.2055771e-07, 9.9999988e-01]], dtype=float32)

# %%
plt.imshow(test[0,:,:,:])
plt.title("Predizione: {}".format(predictions[0]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Predizione: Emergency')

# %%
fig = plt.figure(figsize = (12,12))

for i, immagine in enumerate(test):
  fig.add_subplot(3,5,i+1)
  plt.imshow(immagine)
  plt.title("Predizione: {}".format(predictions[i]))
  plt.tick_params(axis='both', which='both', bottom=False, top=False, left = False,
                  right = False, labelbottom=False, labelleft=False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
