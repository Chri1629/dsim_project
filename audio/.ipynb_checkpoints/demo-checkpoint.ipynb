# %% [markdown]
# # **Progetto di Digital Signal & Image Management**
#
# ## **Parte 1 - Audio recognition- DEMO**
#
#
# *2020/2021*
#
# Peracchi Marco 800578
#
# Uccheddu Christian 800428

# %%
import os
import numpy as np
from time import time
from scipy.io import wavfile as wav
import IPython.display as ipd
import librosa
import librosa.display
import re
#import seaborn as sns
import sounddevice as sd

import matplotlib.pyplot as plt

import pandas as pd

import pickle

#import librosa.display
from sklearn.preprocessing import scale

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import mobilenet
from sklearn.linear_model import LogisticRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-99b5929b8eed> in <module>
#       4 from scipy.io import wavfile as wav
#       5 import IPython.display as ipd
# ----> 6 import librosa
#       7 import librosa.display
#       8 import re
#
# ModuleNotFoundError: No module named 'librosa'

# %%
duration = 7 # (seconds)
rec_rate = 44100
signal = sd.rec(int(duration * rec_rate), samplerate=rec_rate, channels=1, blocking=True)

# %%
signal

# %%
prova = signal[:,0]

# %%
ipd.Audio(prova, rate=rec_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = librosa.feature.melspectrogram(y=prova, n_mels=128)
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111)
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.set_frame_on(False)
S_dB = librosa.power_to_db(spect, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', ax=ax)
fig.savefig("single/test/"+"demo.png", dpi = 100)

# %%
single_processing = keras.preprocessing.image.ImageDataGenerator(preprocessing_function= mobilenet.preprocess_input)

single_generator = single_processing.flow_from_directory("single",
                                    target_size = (224, 224),
                                    color_mode = "rgb",
                                    batch_size = 1,
                                    class_mode = "categorical",
                                    shuffle = False,
                                    seed = 1)
test,label_test = next(single_generator)
# Out:
# Found 1 images belonging to 2 classes.

# %%
model_1 = tf.keras.models.load_model('modello_audio')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-cee7a00f4f6e> in <module>
# ----> 1 model_1 = tf.keras.models.load_model('modello_audio')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144       h5py is not None and (
#     145           isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     198   opened_new_file = not isinstance(filepath, h5py.File)
#     199   if opened_new_file:
# --> 200     f = h5py.File(filepath, mode='r')
#     201   else:
#     202     f = filepath
#
# ~/opt/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file read failed: time = Thu Jan 14 17:25:36 2021
# , filename = 'modello_audio', file descriptor = 73, errno = 21, error message = 'Is a directory', buf = 0x7ffeee29ebe8, total read size = 8, bytes this sub-read = 8, bytes actually read = 18446744073709551615, offset = 0)

# %%
loaded_model = pickle.load(open("logistic_audio.sav", 'rb'))

# %%
model_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b06f66b5db51> in <module>
# ----> 1 model_1
#
# NameError: name 'model_1' is not defined

# %%
test_features = model_1.predict(test)
test_features = test_features.reshape(test_features.shape[0],
                                      test_features.shape[1]*test_features.shape[2]*test_features.shape[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b5aa4ef216b5> in <module>
# ----> 1 test_features = model_1.predict(test)
#       2 test_features = test_features.reshape(test_features.shape[0],
#       3                                       test_features.shape[1]*test_features.shape[2]*test_features.shape[3])
#
# NameError: name 'model_1' is not defined

# %%
pred_finali = loaded_model.predict(test_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ee7b400d43f3> in <module>
# ----> 1 pred_finali = loaded_model.predict(test_features)
#
# NameError: name 'test_features' is not defined

# %%
pred_finali
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-dcb2f74286fe> in <module>
# ----> 1 pred_finali
#
# NameError: name 'pred_finali' is not defined

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in pred_finali]

predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-44abaafb77d5> in <module>
# ----> 1 labels = (train_generator.class_indices)
#       2 labels = dict((v,k) for k,v in labels.items())
#       3 predictions = [labels[k] for k in pred_finali]
#       4
#       5 predictions
#
# NameError: name 'train_generator' is not defined
